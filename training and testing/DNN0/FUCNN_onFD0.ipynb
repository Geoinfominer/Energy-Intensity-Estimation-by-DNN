# %% [markdown]
# # this notebook was initially run on Google Colab

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Jan 27 02:48:29 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # import libraries

# %%
'''
import libraries
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Model
from tensorflow.keras.optimizers import Adam
import os
import random
random.seed(0)
tf.random.set_seed(0)
np.random.seed(0)
os.environ['PYTHONHASHSEED'] = str(0)

# %% [markdown]
# # define variables

# %%
features = ['lucc_0','lucc_1','lucc_2','lucc_3','lucc_4','lucc_5','b1','b2','b3','b4','b5','b6','b7','lst','ndvi','ntl','elevation','entropy','max_x','max_y','min_x','min_y']
GeoFeas = ['lucc_0','lucc_1','lucc_2','lucc_3','lucc_4','lucc_5','b1','b2','b3','b4','b5','b6','b7','lst','ndvi','ntl','elevation','entropy']
CoordFeas = ['max_x','max_y','min_x','min_y']
years = list(range(2001,2018))
provs30 = ['Qinghai','Guizhou','Guangxi','Xinjiang','Chongqing','Jilin','Sichuan','Hubei','Beijing',
      'Liaoning','Heilongjiang','Shandong','Guangdong','Hebei','Henan','Hainan','Ningxia',
      'Gansu','Neimenggu','Tianjin','Shanxi_jin','Yunnan','Fujian','Jiangxi','Anhui',
      'Hunan','Jiangsu','Zhejiang','Shanghai','Shanxi_qin']
dir_csv = '/boot/'

# %% [markdown]
# # read data and preprocess

# %%
'''
read one fold(we use 4-fold cross validation)
'''
trainDf = pd.read_csv('fd0_TrainData.csv')
devDf = pd.read_csv('fd0_TestData.csv')

# %%
''' convert into numpy '''
def convert_fromDF_toNP(full_df_):
  full_arr_ = full_df_[GeoFeas+['ei1000']].to_numpy()
  return full_arr_

# %%
train_arr = convert_fromDF_toNP(trainDf)
dev_arr = convert_fromDF_toNP(devDf)
print(train_arr.shape)
# Out:
# (382, 19)

# %%
import matplotlib.pyplot as plt
# show the distribution of the dev_arr dataset
plt.figure(figsize=(30,40))
for i in range(19): 
    ax = plt.subplot(7, 7, i + 1)
    plt.hist(dev_arr[:,i],bins=40)
    plt.title(trainDf.columns[i+2])

# %%
''' normalization '''
def normalize_features(train_part,dev_part):
  ''' !DON'T normalize ei1000 '''
  ''' !DON'T normalize ei1000 '''
  ''' !DON'T normalize ei1000 '''
  '''
  train_part and dev_part are numpy arr.
  '''
  # fit normalizer
  '''
  from sklearn.preprocessing import MinMaxScaler
  scaler = MinMaxScaler()
  scaler.fit(train_part[:,:-1])
  '''
  
  from sklearn.preprocessing import PowerTransformer
  scaler = PowerTransformer(method='yeo-johnson')
  scaler.fit(train_part[:,:-1])
  
  '''
  from sklearn.preprocessing import QuantileTransformer 
  scaler = QuantileTransformer(n_quantiles=len(train_part),output_distribution='normal', random_state=0) 
  scaler.fit(train_part[:,:-1])
  '''
  # transform
  train_part[:,:-1] = scaler.transform(train_part[:,:-1])
  dev_part[:,:-1] = scaler.transform(dev_part[:,:-1])

  return train_part,dev_part,scaler

# %%
train_arr,dev_arr,scaler = normalize_features(train_arr,dev_arr)

# %%
# show the distribution of the dev_part
plt.figure(figsize=(30,40))
for i in range(19): 
    ax = plt.subplot(7, 7, i + 1)
    plt.hist(dev_arr[:,i],bins=40)
    plt.title(devDf.columns[i+2])

# %%
''' convert into tf.data.Dataset '''
def generateTFDataset(arr):
  ''' arr contains features and labels '''
  ds = tf.data.Dataset.from_tensor_slices(arr)
  ds = ds.map(lambda ts:(ts[:-1],ts[-1]))
  ds = ds.shuffle(510)
  ds = ds.batch(510)
  return ds

# %%
ds_train = generateTFDataset(train_arr)
ds_dev = generateTFDataset(dev_arr)

# %% [markdown]
# # define model

# %%
''' build model '''
def create_model(input_shape):
  ''' input_shape,say,is (18,)  '''
  # set seed=0 in the weight initializer
  weight_init = tf.keras.initializers.GlorotUniform(seed = 0)

  # input layer: corresponding to embedding matrix
  x_input = keras.layers.Input(shape = input_shape)

  # model body
  x = keras.layers.Dense(32,activation = "relu", kernel_initializer=weight_init)(x_input)
  x = keras.layers.Dense(32,activation = "relu", kernel_initializer=weight_init)(x)
  x = keras.layers.Dense(16,activation = "relu", kernel_initializer=weight_init)(x)
  x = keras.layers.Dense(8,activation = "relu", kernel_initializer=weight_init)(x)
  x = keras.layers.Dense(8,activation = "relu", kernel_initializer=weight_init)(x)
  x = keras.layers.Dense(1,activation = "relu", kernel_initializer=weight_init)(x)

  # summary
  model = Model(inputs = x_input, outputs = x)
  return model

# %%
''' customizing metric R2 '''
def R2(y_true, y_pred):
  if type(y_true) == 'numpy.ndarray':
    y_true = tf.constant(y_true)
    y_pred = tf.constant(y_pred)
  flat_ture = tf.reshape(y_true, [-1])
  flat_prd = tf.reshape(y_pred, [-1])
  RSS = tf.math.reduce_sum((tf.math.square(flat_ture - flat_prd)),axis=-1)
  TSS = tf.math.reduce_sum(tf.math.square(flat_ture - tf.reduce_mean(flat_ture,axis=-1)))
  return 1-RSS/TSS

# %% [markdown]
# # run model

# %%
''' run model '''
def run_model(train_df_ = None, dev_df_ = None,lr_ = None,epo = None,checkpoint_path=None):

  # convert into numpy
  print('convert into numpy... ...')
  train_arr = convert_fromDF_toNP(train_df_)
  dev_arr = convert_fromDF_toNP(dev_df_)

  # normalization
  print('normalization... ...')
  train_arr,dev_arr,scaler = normalize_features(train_arr,dev_arr)

  # convert into tf.data.Dataset
  print('convert into tf.data.Dataset... ...')
  ds_train = generateTFDataset(train_arr)
  ds_dev = generateTFDataset(dev_arr)

  # build model
  print('build model... ...')
  model = create_model(train_arr.shape[1]-1)

  # compile model
  print('compile model... ...')
  opt = Adam(lr=lr_) 
  model.compile(loss=tf.keras.losses.MeanSquaredError(), 
         optimizer=opt, 
         metrics=[tf.keras.metrics.RootMeanSquaredError(),R2])
  model.summary()
  cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,save_best_only=True, save_weights_only=True, verbose=0)
  reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                           factor=0.95, 
                           patience=15, 
                           verbose=1)

  # fit model
  history = model.fit(
        ds_train,
        epochs=epo,
        validation_data=ds_dev,
        callbacks=[cp_callback,reduce_lr],
        verbose = 0)
  
  # reload best_model
  bestModel = create_model(train_arr.shape[1]-1)
  bestModel.compile(loss=tf.keras.losses.MeanSquaredError(), 
           optimizer=opt, 
           metrics=[tf.keras.metrics.RootMeanSquaredError(),R2])
  bestModel.load_weights(checkpoint_path)

  # return best_model and parameters
  return {
      'bestModel' : bestModel,
      'history' : history,
      'train_dev_set' : (train_arr,dev_arr),
      'normalizer' : scaler
      }

# %%
result = run_model(
          train_df_ = trainDf, dev_df_ = devDf,
          lr_ = 0.001,
          epo = 10000,
          checkpoint_path='/boot/cp.best.ckpt'
          )
# Out:
# convert into numpy... ...
# normalization... ...
# convert into tf.data.Dataset... ...
# build model... ...
# compile model... ...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 18)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                608
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_15 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_16 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 2,409
# Trainable params: 2,409
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 01832: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
#
# Epoch 01978: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
#
# Epoch 02001: ReduceLROnPlateau reducing learning rate to 0.0008573750033974647.
#
# Epoch 02140: ReduceLROnPlateau reducing learning rate to 0.0008145062311086804.
#
# Epoch 02188: ReduceLROnPlateau reducing learning rate to 0.0007737808919046074.
#
# Epoch 02208: ReduceLROnPlateau reducing learning rate to 0.000735091819660738.
#
# Epoch 02223: ReduceLROnPlateau reducing learning rate to 0.0006983372120885178.
#
# Epoch 02249: ReduceLROnPlateau reducing learning rate to 0.0006634203542489559.
#
# Epoch 02264: ReduceLROnPlateau reducing learning rate to 0.0006302493420662358.
#
# Epoch 02282: ReduceLROnPlateau reducing learning rate to 0.0005987368611386045.
#
# Epoch 02305: ReduceLROnPlateau reducing learning rate to 0.0005688000208465382.
#
# Epoch 02330: ReduceLROnPlateau reducing learning rate to 0.0005403600225690752.
#
# Epoch 02345: ReduceLROnPlateau reducing learning rate to 0.0005133419937919825.
#
# Epoch 02360: ReduceLROnPlateau reducing learning rate to 0.0004876748775132.
#
# Epoch 02379: ReduceLROnPlateau reducing learning rate to 0.00046329112810781223.
#
# Epoch 02394: ReduceLROnPlateau reducing learning rate to 0.00044012657308485355.
#
# Epoch 02409: ReduceLROnPlateau reducing learning rate to 0.00041812024719547477.
#
# Epoch 02424: ReduceLROnPlateau reducing learning rate to 0.00039721422654110934.
#
# Epoch 02439: ReduceLROnPlateau reducing learning rate to 0.00037735351797891776.
#
# Epoch 02454: ReduceLROnPlateau reducing learning rate to 0.00035848583793267607.
#
# Epoch 02469: ReduceLROnPlateau reducing learning rate to 0.00034056155709549785.
#
# Epoch 02484: ReduceLROnPlateau reducing learning rate to 0.00032353347924072293.
#
# Epoch 02499: ReduceLROnPlateau reducing learning rate to 0.00030735681357327847.
#
# Epoch 02514: ReduceLROnPlateau reducing learning rate to 0.00029198898118920624.
#
# Epoch 02529: ReduceLROnPlateau reducing learning rate to 0.00027738953212974593.
#
# Epoch 02544: ReduceLROnPlateau reducing learning rate to 0.0002635200624354184.
#
# Epoch 02559: ReduceLROnPlateau reducing learning rate to 0.0002503440482541919.
#
# Epoch 02574: ReduceLROnPlateau reducing learning rate to 0.00023782684584148226.
#
# Epoch 02589: ReduceLROnPlateau reducing learning rate to 0.00022593549801968037.
#
# Epoch 02604: ReduceLROnPlateau reducing learning rate to 0.00021463872035383245.
#
# Epoch 02619: ReduceLROnPlateau reducing learning rate to 0.0002039067905570846.
#
# Epoch 02634: ReduceLROnPlateau reducing learning rate to 0.00019371145172044634.
#
# Epoch 02649: ReduceLROnPlateau reducing learning rate to 0.00018402588466415182.
#
# Epoch 02664: ReduceLROnPlateau reducing learning rate to 0.00017482458351878447.
#
# Epoch 02753: ReduceLROnPlateau reducing learning rate to 0.0001660833557252772.
#
# Epoch 02768: ReduceLROnPlateau reducing learning rate to 0.0001577791837917175.
#
# Epoch 02785: ReduceLROnPlateau reducing learning rate to 0.0001498902252933476.
#
# Epoch 02800: ReduceLROnPlateau reducing learning rate to 0.00014239571610232815.
#
# Epoch 02815: ReduceLROnPlateau reducing learning rate to 0.00013527592891477978.
#
# Epoch 02845: ReduceLROnPlateau reducing learning rate to 0.00012851213177782482.
#
# Epoch 02860: ReduceLROnPlateau reducing learning rate to 0.00012208651896798982.
#
# Epoch 02875: ReduceLROnPlateau reducing learning rate to 0.00011598219716688617.
#
# Epoch 02890: ReduceLROnPlateau reducing learning rate to 0.00011018308869097381.
#
# Epoch 02905: ReduceLROnPlateau reducing learning rate to 0.00010467393149156123.
#
# Epoch 02922: ReduceLROnPlateau reducing learning rate to 9.944023768184706e-05.
#
# Epoch 02948: ReduceLROnPlateau reducing learning rate to 9.446822441532275e-05.
#
# Epoch 02963: ReduceLROnPlateau reducing learning rate to 8.974481388577259e-05.
#
# Epoch 02979: ReduceLROnPlateau reducing learning rate to 8.525757111783605e-05.
#
# Epoch 02994: ReduceLROnPlateau reducing learning rate to 8.099469014268834e-05.
#
# Epoch 03009: ReduceLROnPlateau reducing learning rate to 7.694495252508204e-05.
#
# Epoch 03024: ReduceLROnPlateau reducing learning rate to 7.309770662686787e-05.
#
# Epoch 03060: ReduceLROnPlateau reducing learning rate to 6.944281922187656e-05.
#
# Epoch 03075: ReduceLROnPlateau reducing learning rate to 6.597067549591884e-05.
#
# Epoch 03090: ReduceLROnPlateau reducing learning rate to 6.267214448598679e-05.
#
# Epoch 03105: ReduceLROnPlateau reducing learning rate to 5.953853760729544e-05.
#
# Epoch 03120: ReduceLROnPlateau reducing learning rate to 5.656161210936261e-05.
#
# Epoch 03135: ReduceLROnPlateau reducing learning rate to 5.373353305913042e-05.
#
# Epoch 03150: ReduceLROnPlateau reducing learning rate to 5.104685606056591e-05.
#
# Epoch 03165: ReduceLROnPlateau reducing learning rate to 4.849451343034161e-05.
#
# Epoch 03180: ReduceLROnPlateau reducing learning rate to 4.606978654919658e-05.
#
# Epoch 03195: ReduceLROnPlateau reducing learning rate to 4.3766295493696814e-05.
#
# Epoch 03210: ReduceLROnPlateau reducing learning rate to 4.1577981755835934e-05.
#
# Epoch 03225: ReduceLROnPlateau reducing learning rate to 3.949908405047608e-05.
#
# Epoch 03240: ReduceLROnPlateau reducing learning rate to 3.752413140318822e-05.
#
# Epoch 03255: ReduceLROnPlateau reducing learning rate to 3.564792586985277e-05.
#
# Epoch 03270: ReduceLROnPlateau reducing learning rate to 3.3865528712340166e-05.
#
# Epoch 03285: ReduceLROnPlateau reducing learning rate to 3.217225348635111e-05.
#
# Epoch 03300: ReduceLROnPlateau reducing learning rate to 3.0563641848857516e-05.
#
# Epoch 03315: ReduceLROnPlateau reducing learning rate to 2.9035460102022626e-05.
#
# Epoch 03330: ReduceLROnPlateau reducing learning rate to 2.7583687096921494e-05.
#
# Epoch 03345: ReduceLROnPlateau reducing learning rate to 2.620450213726144e-05.
#
# Epoch 03360: ReduceLROnPlateau reducing learning rate to 2.4894276339182395e-05.
#
# Epoch 03375: ReduceLROnPlateau reducing learning rate to 2.3649562263017287e-05.
#
# Epoch 03390: ReduceLROnPlateau reducing learning rate to 2.2467083545052444e-05.
#
# Epoch 03405: ReduceLROnPlateau reducing learning rate to 2.134372971340781e-05.
#
# Epoch 03420: ReduceLROnPlateau reducing learning rate to 2.0276544091757387e-05.
#
# Epoch 03435: ReduceLROnPlateau reducing learning rate to 1.9262716887169517e-05.
#
# Epoch 03450: ReduceLROnPlateau reducing learning rate to 1.8299581734027014e-05.
#
# Epoch 03465: ReduceLROnPlateau reducing learning rate to 1.7384601869707693e-05.
#
# Epoch 03480: ReduceLROnPlateau reducing learning rate to 1.6515371862624305e-05.
#
# Epoch 03495: ReduceLROnPlateau reducing learning rate to 1.568960378790507e-05.
#
# Epoch 03510: ReduceLROnPlateau reducing learning rate to 1.490512377131381e-05.
#
# Epoch 03525: ReduceLROnPlateau reducing learning rate to 1.4159867669150115e-05.
#
# Epoch 03547: ReduceLROnPlateau reducing learning rate to 1.3451874156089615e-05.
#
# Epoch 03562: ReduceLROnPlateau reducing learning rate to 1.2779280405084136e-05.
#
# Epoch 03583: ReduceLROnPlateau reducing learning rate to 1.2140316039221942e-05.
#
# Epoch 03598: ReduceLROnPlateau reducing learning rate to 1.1533300539667834e-05.
#
# Epoch 03613: ReduceLROnPlateau reducing learning rate to 1.0956635469483444e-05.
#
# Epoch 03628: ReduceLROnPlateau reducing learning rate to 1.0408803609607275e-05.
#
# Epoch 03643: ReduceLROnPlateau reducing learning rate to 9.888363774734898e-06.
#
# Epoch 03658: ReduceLROnPlateau reducing learning rate to 9.393945629199151e-06.
#
# Epoch 03673: ReduceLROnPlateau reducing learning rate to 8.92424795893021e-06.
#
# Epoch 03699: ReduceLROnPlateau reducing learning rate to 8.478035215375711e-06.
#
# Epoch 03714: ReduceLROnPlateau reducing learning rate to 8.054133195400936e-06.
#
# Epoch 03729: ReduceLROnPlateau reducing learning rate to 7.651426449228893e-06.
#
# Epoch 03744: ReduceLROnPlateau reducing learning rate to 7.2688548243604595e-06.
#
# Epoch 03791: ReduceLROnPlateau reducing learning rate to 6.905412169544433e-06.
#
# Epoch 03806: ReduceLROnPlateau reducing learning rate to 6.5601415826677105e-06.
#
# Epoch 03821: ReduceLROnPlateau reducing learning rate to 6.2321345467353235e-06.
#
# Epoch 03836: ReduceLROnPlateau reducing learning rate to 5.920527905800554e-06.
#
# Epoch 03851: ReduceLROnPlateau reducing learning rate to 5.624501704915019e-06.
#
# Epoch 03866: ReduceLROnPlateau reducing learning rate to 5.343276598068769e-06.
#
# Epoch 03891: ReduceLROnPlateau reducing learning rate to 5.076112984170322e-06.
#
# Epoch 03906: ReduceLROnPlateau reducing learning rate to 4.8223071189568145e-06.
#
# Epoch 03940: ReduceLROnPlateau reducing learning rate to 4.581191979013965e-06.
#
# Epoch 03955: ReduceLROnPlateau reducing learning rate to 4.352132509666262e-06.
#
# Epoch 03970: ReduceLROnPlateau reducing learning rate to 4.134526056986942e-06.
#
# Epoch 03985: ReduceLROnPlateau reducing learning rate to 3.927799775738094e-06.
#
# Epoch 04000: ReduceLROnPlateau reducing learning rate to 3.7314097653506904e-06.
#
# Epoch 04015: ReduceLROnPlateau reducing learning rate to 3.5448393418846533e-06.
#
# Epoch 04030: ReduceLROnPlateau reducing learning rate to 3.3675973099889233e-06.
#
# Epoch 04045: ReduceLROnPlateau reducing learning rate to 3.199217530891474e-06.
#
# Epoch 04060: ReduceLROnPlateau reducing learning rate to 3.039256762349396e-06.
#
# Epoch 04075: ReduceLROnPlateau reducing learning rate to 2.887294010633923e-06.
#
# Epoch 04090: ReduceLROnPlateau reducing learning rate to 2.7429292345004796e-06.
#
# Epoch 04105: ReduceLROnPlateau reducing learning rate to 2.6057826971737086e-06.
#
# Epoch 04120: ReduceLROnPlateau reducing learning rate to 2.4754936703175187e-06.
#
# Epoch 04135: ReduceLROnPlateau reducing learning rate to 2.3517189220001454e-06.
#
# Epoch 04150: ReduceLROnPlateau reducing learning rate to 2.2341329326991397e-06.
#
# Epoch 04165: ReduceLROnPlateau reducing learning rate to 2.122426383266429e-06.
#
# Epoch 04180: ReduceLROnPlateau reducing learning rate to 2.0163050749033573e-06.
#
# Epoch 04195: ReduceLROnPlateau reducing learning rate to 1.915489929160685e-06.
#
# Epoch 04210: ReduceLROnPlateau reducing learning rate to 1.8197154759036493e-06.
#
# Epoch 04225: ReduceLROnPlateau reducing learning rate to 1.728729745309465e-06.
#
# Epoch 04240: ReduceLROnPlateau reducing learning rate to 1.6422932958448655e-06.
#
# Epoch 04255: ReduceLROnPlateau reducing learning rate to 1.5601786742536206e-06.
#
# Epoch 04270: ReduceLROnPlateau reducing learning rate to 1.4821697675415633e-06.
#
# Epoch 04285: ReduceLROnPlateau reducing learning rate to 1.408061262964111e-06.
#
# Epoch 04300: ReduceLROnPlateau reducing learning rate to 1.3376582160162797e-06.
#
# Epoch 04315: ReduceLROnPlateau reducing learning rate to 1.2707752944152161e-06.
#
# Epoch 04330: ReduceLROnPlateau reducing learning rate to 1.207236562095204e-06.
#
# Epoch 04345: ReduceLROnPlateau reducing learning rate to 1.1468747231901943e-06.
#
# Epoch 04360: ReduceLROnPlateau reducing learning rate to 1.0895310140313086e-06.
#
# Epoch 04375: ReduceLROnPlateau reducing learning rate to 1.0350544471293687e-06.
#
# Epoch 04390: ReduceLROnPlateau reducing learning rate to 9.833017031724012e-07.
#
# Epoch 04405: ReduceLROnPlateau reducing learning rate to 9.341365910131571e-07.
#
# Epoch 04420: ReduceLROnPlateau reducing learning rate to 8.874297776628737e-07.
#
# Epoch 04435: ReduceLROnPlateau reducing learning rate to 8.43058302280042e-07.
#
# Epoch 04450: ReduceLROnPlateau reducing learning rate to 8.009053601654159e-07.
#
# Epoch 04465: ReduceLROnPlateau reducing learning rate to 7.608600867570203e-07.
#
# Epoch 04480: ReduceLROnPlateau reducing learning rate to 7.228170716189196e-07.
#
# Epoch 04495: ReduceLROnPlateau reducing learning rate to 6.866761964374745e-07.
#
# Epoch 04510: ReduceLROnPlateau reducing learning rate to 6.523423650151017e-07.
#
# Epoch 04525: ReduceLROnPlateau reducing learning rate to 6.197252332640346e-07.
#
# Epoch 04540: ReduceLROnPlateau reducing learning rate to 5.887389932013321e-07.
#
# Epoch 04555: ReduceLROnPlateau reducing learning rate to 5.593020489413902e-07.
#
# Epoch 04570: ReduceLROnPlateau reducing learning rate to 5.313369626946951e-07.
#
# Epoch 04585: ReduceLROnPlateau reducing learning rate to 5.047701307603347e-07.
#
# Epoch 04600: ReduceLROnPlateau reducing learning rate to 4.795316215222556e-07.
#
# Epoch 04615: ReduceLROnPlateau reducing learning rate to 4.5555506744676677e-07.
#
# Epoch 04630: ReduceLROnPlateau reducing learning rate to 4.327773140744284e-07.
#
# Epoch 04645: ReduceLROnPlateau reducing learning rate to 4.111384470206758e-07.
#
# Epoch 04660: ReduceLROnPlateau reducing learning rate to 3.905815219695796e-07.
#
# Epoch 04675: ReduceLROnPlateau reducing learning rate to 3.710524566713502e-07.
#
# Epoch 04690: ReduceLROnPlateau reducing learning rate to 3.524998419379699e-07.
#
# Epoch 04705: ReduceLROnPlateau reducing learning rate to 3.3487486064132097e-07.
#
# Epoch 04720: ReduceLROnPlateau reducing learning rate to 3.1813112570944214e-07.
#
# Epoch 04735: ReduceLROnPlateau reducing learning rate to 3.022245721240324e-07.
#
# Epoch 04750: ReduceLROnPlateau reducing learning rate to 2.871133489179556e-07.
#
# Epoch 04765: ReduceLROnPlateau reducing learning rate to 2.727576841721202e-07.
#
# Epoch 04780: ReduceLROnPlateau reducing learning rate to 2.591198040136078e-07.
#
# Epoch 04795: ReduceLROnPlateau reducing learning rate to 2.46163824613177e-07.
#
# Epoch 04810: ReduceLROnPlateau reducing learning rate to 2.3385564418276772e-07.
#
# Epoch 04825: ReduceLROnPlateau reducing learning rate to 2.2216286197362933e-07.
#
# Epoch 04840: ReduceLROnPlateau reducing learning rate to 2.1105472427507264e-07.
#
# Epoch 04855: ReduceLROnPlateau reducing learning rate to 2.005019894113502e-07.
#
# Epoch 04870: ReduceLROnPlateau reducing learning rate to 1.904768872407203e-07.
#
# Epoch 04885: ReduceLROnPlateau reducing learning rate to 1.809530381535751e-07.
#
# Epoch 04900: ReduceLROnPlateau reducing learning rate to 1.7190538557088075e-07.
#
# Epoch 04915: ReduceLROnPlateau reducing learning rate to 1.633101149423055e-07.
#
# Epoch 04930: ReduceLROnPlateau reducing learning rate to 1.5514461324528383e-07.
#
# Epoch 04945: ReduceLROnPlateau reducing learning rate to 1.4738738798314444e-07.
#
# Epoch 04960: ReduceLROnPlateau reducing learning rate to 1.4001801318386242e-07.
#
# Epoch 04975: ReduceLROnPlateau reducing learning rate to 1.330171158997473e-07.
#
# Epoch 04990: ReduceLROnPlateau reducing learning rate to 1.2636625470463514e-07.
#
# Epoch 05005: ReduceLROnPlateau reducing learning rate to 1.2004794669451258e-07.
#
# Epoch 05020: ReduceLROnPlateau reducing learning rate to 1.1404554598470895e-07.
#
# Epoch 05035: ReduceLROnPlateau reducing learning rate to 1.0834327071052029e-07.
#
# Epoch 05050: ReduceLROnPlateau reducing learning rate to 1.0292610852502548e-07.
#
# Epoch 05065: ReduceLROnPlateau reducing learning rate to 9.77798030987742e-08.
#
# Epoch 05080: ReduceLROnPlateau reducing learning rate to 9.289081361885109e-08.
#
# Epoch 05095: ReduceLROnPlateau reducing learning rate to 8.824627428793974e-08.
#
# Epoch 05110: ReduceLROnPlateau reducing learning rate to 8.383396057354275e-08.
#
# Epoch 05125: ReduceLROnPlateau reducing learning rate to 7.964226220735781e-08.
#
# Epoch 05140: ReduceLROnPlateau reducing learning rate to 7.566014943449773e-08.
#
# Epoch 05155: ReduceLROnPlateau reducing learning rate to 7.187713926271044e-08.
#
# Epoch 05170: ReduceLROnPlateau reducing learning rate to 6.828328196206712e-08.
#
# Epoch 05185: ReduceLROnPlateau reducing learning rate to 6.486912056402616e-08.
#
# Epoch 05200: ReduceLROnPlateau reducing learning rate to 6.162566386080926e-08.
#
# Epoch 05215: ReduceLROnPlateau reducing learning rate to 5.854437965524539e-08.
#
# Epoch 05230: ReduceLROnPlateau reducing learning rate to 5.561716100999092e-08.
#
# Epoch 05245: ReduceLROnPlateau reducing learning rate to 5.2836302621983573e-08.
#
# Epoch 05260: ReduceLROnPlateau reducing learning rate to 5.0194487322130494e-08.
#
# Epoch 05275: ReduceLROnPlateau reducing learning rate to 4.768476244976227e-08.
#
# Epoch 05290: ReduceLROnPlateau reducing learning rate to 4.530052297724296e-08.
#
# Epoch 05305: ReduceLROnPlateau reducing learning rate to 4.303549800965811e-08.
#
# Epoch 05320: ReduceLROnPlateau reducing learning rate to 4.0883723784190804e-08.
#
# Epoch 05335: ReduceLROnPlateau reducing learning rate to 3.883953691996567e-08.
#
# Epoch 05350: ReduceLROnPlateau reducing learning rate to 3.689756091773688e-08.
#
# Epoch 05365: ReduceLROnPlateau reducing learning rate to 3.505268253434224e-08.
#
# Epoch 05380: ReduceLROnPlateau reducing learning rate to 3.3300048407625126e-08.
#
# Epoch 05395: ReduceLROnPlateau reducing learning rate to 3.163504480596657e-08.
#
# Epoch 05410: ReduceLROnPlateau reducing learning rate to 3.005329425320724e-08.
#
# Epoch 05425: ReduceLROnPlateau reducing learning rate to 2.855062852802348e-08.
#
# Epoch 05440: ReduceLROnPlateau reducing learning rate to 2.7123097101622307e-08.
#
# Epoch 05455: ReduceLROnPlateau reducing learning rate to 2.576694182465644e-08.
#
# Epoch 05470: ReduceLROnPlateau reducing learning rate to 2.4478595239685317e-08.
#
# Epoch 05485: ReduceLROnPlateau reducing learning rate to 2.32546653933241e-08.
#
# Epoch 05500: ReduceLROnPlateau reducing learning rate to 2.2091932461165697e-08.
#
# Epoch 05515: ReduceLROnPlateau reducing learning rate to 2.0987335247468764e-08.
#
# Epoch 05530: ReduceLROnPlateau reducing learning rate to 1.9937967810079724e-08.
#
# Epoch 05545: ReduceLROnPlateau reducing learning rate to 1.894106933519879e-08.
#
# Epoch 05560: ReduceLROnPlateau reducing learning rate to 1.799401569968495e-08.
#
# Epoch 05575: ReduceLROnPlateau reducing learning rate to 1.7094314408439004e-08.
#
# Epoch 05590: ReduceLROnPlateau reducing learning rate to 1.623959953178655e-08.
#
# Epoch 05605: ReduceLROnPlateau reducing learning rate to 1.5427619892705025e-08.
#
# Epoch 05620: ReduceLROnPlateau reducing learning rate to 1.4656239066823672e-08.
#
# Epoch 05635: ReduceLROnPlateau reducing learning rate to 1.392342694472859e-08.
#
# Epoch 05650: ReduceLROnPlateau reducing learning rate to 1.322725551311521e-08.
#
# Epoch 05665: ReduceLROnPlateau reducing learning rate to 1.2565892948401824e-08.
#
# Epoch 05680: ReduceLROnPlateau reducing learning rate to 1.1937598554112583e-08.
#
# Epoch 05695: ReduceLROnPlateau reducing learning rate to 1.1340718542030003e-08.
#
# Epoch 05710: ReduceLROnPlateau reducing learning rate to 1.0773682657116978e-08.
#
# Epoch 05725: ReduceLROnPlateau reducing learning rate to 1.023499827113028e-08.
#
# Epoch 05740: ReduceLROnPlateau reducing learning rate to 9.723248695081565e-09.
#
# Epoch 05755: ReduceLROnPlateau reducing learning rate to 9.237086429081387e-09.
#
# Epoch 05770: ReduceLROnPlateau reducing learning rate to 8.775232318569692e-09.
#
# Epoch 05785: ReduceLROnPlateau reducing learning rate to 8.336470491698833e-09.
#
# Epoch 05800: ReduceLROnPlateau reducing learning rate to 7.919646671794566e-09.
#
# Epoch 05815: ReduceLROnPlateau reducing learning rate to 7.523663958508563e-09.
#
# Epoch 05830: ReduceLROnPlateau reducing learning rate to 7.14748114027941e-09.
#
# Epoch 05845: ReduceLROnPlateau reducing learning rate to 6.790107209830864e-09.
#
# Epoch 05860: ReduceLROnPlateau reducing learning rate to 6.450601786056608e-09.
#
# Epoch 05875: ReduceLROnPlateau reducing learning rate to 6.128071738942253e-09.
#
# Epoch 05890: ReduceLROnPlateau reducing learning rate to 5.82166823637209e-09.
#
# Epoch 05905: ReduceLROnPlateau reducing learning rate to 5.5305846347053486e-09.
#
# Epoch 05920: ReduceLROnPlateau reducing learning rate to 5.254055213121944e-09.
#
# Epoch 05935: ReduceLROnPlateau reducing learning rate to 4.991352642313984e-09.
#
# Epoch 05950: ReduceLROnPlateau reducing learning rate to 4.741785031292523e-09.
#
# Epoch 05965: ReduceLROnPlateau reducing learning rate to 4.504695927387558e-09.
#
# Epoch 05980: ReduceLROnPlateau reducing learning rate to 4.279460941170043e-09.
#
# Epoch 05995: ReduceLROnPlateau reducing learning rate to 4.0654877464518786e-09.
#
# Epoch 06010: ReduceLROnPlateau reducing learning rate to 3.862213548977422e-09.
#
# Epoch 06025: ReduceLROnPlateau reducing learning rate to 3.6691029769997383e-09.
#
# Epoch 06040: ReduceLROnPlateau reducing learning rate to 3.4856478703382264e-09.
#
# Epoch 06055: ReduceLROnPlateau reducing learning rate to 3.3113653818972463e-09.
#
# Epoch 06070: ReduceLROnPlateau reducing learning rate to 3.1457971338966215e-09.
#
# Epoch 06085: ReduceLROnPlateau reducing learning rate to 2.9885073193902654e-09.
#
# Epoch 06100: ReduceLROnPlateau reducing learning rate to 2.8390818584966837e-09.
#
# Epoch 06115: ReduceLROnPlateau reducing learning rate to 2.6971277655718494e-09.
#
# Epoch 06130: ReduceLROnPlateau reducing learning rate to 2.5622714616702067e-09.
#
# Epoch 06145: ReduceLROnPlateau reducing learning rate to 2.4341579307751715e-09.
#
# Epoch 06160: ReduceLROnPlateau reducing learning rate to 2.3124500869720065e-09.
#
# Epoch 06175: ReduceLROnPlateau reducing learning rate to 2.196827508793575e-09.
#
# Epoch 06190: ReduceLROnPlateau reducing learning rate to 2.086986228277965e-09.
#
# Epoch 06205: ReduceLROnPlateau reducing learning rate to 1.982636832487117e-09.
#
# Epoch 06220: ReduceLROnPlateau reducing learning rate to 1.8835048853915738e-09.
#
# Epoch 06235: ReduceLROnPlateau reducing learning rate to 1.7893296622162323e-09.
#
# Epoch 06250: ReduceLROnPlateau reducing learning rate to 1.6998632001996582e-09.
#
# Epoch 06265: ReduceLROnPlateau reducing learning rate to 1.6148700876517095e-09.
#
# Epoch 06280: ReduceLROnPlateau reducing learning rate to 1.5341266201840396e-09.
#
# Epoch 06295: ReduceLROnPlateau reducing learning rate to 1.4574202733541596e-09.
#
# Epoch 06310: ReduceLROnPlateau reducing learning rate to 1.3845492807806892e-09.
#
# Epoch 06325: ReduceLROnPlateau reducing learning rate to 1.3153217903738578e-09.
#
# Epoch 06340: ReduceLROnPlateau reducing learning rate to 1.2495556533931307e-09.
#
# Epoch 06355: ReduceLROnPlateau reducing learning rate to 1.187077897091271e-09.
#
# Epoch 06370: ReduceLROnPlateau reducing learning rate to 1.1277239864160294e-09.
#
# Epoch 06385: ReduceLROnPlateau reducing learning rate to 1.0713378240101434e-09.
#
# Epoch 06400: ReduceLROnPlateau reducing learning rate to 1.0177709064418394e-09.
#
# Epoch 06415: ReduceLROnPlateau reducing learning rate to 9.668823242048319e-10.
#
# Epoch 06430: ReduceLROnPlateau reducing learning rate to 9.185382343623871e-10.
#
# Epoch 06445: ReduceLROnPlateau reducing learning rate to 8.726113331913864e-10.
#
# Epoch 06460: ReduceLROnPlateau reducing learning rate to 8.289807507111391e-10.
#
# Epoch 06475: ReduceLROnPlateau reducing learning rate to 7.875317342698196e-10.
#
# Epoch 06490: ReduceLROnPlateau reducing learning rate to 7.481551211885318e-10.
#
# Epoch 06505: ReduceLROnPlateau reducing learning rate to 7.107473387613083e-10.
#
# Epoch 06520: ReduceLROnPlateau reducing learning rate to 6.752099823703616e-10.
#
# Epoch 06535: ReduceLROnPlateau reducing learning rate to 6.414494990725217e-10.
#
# Epoch 06550: ReduceLROnPlateau reducing learning rate to 6.09377029392455e-10.
#
# Epoch 06565: ReduceLROnPlateau reducing learning rate to 5.7890819638029e-10.
#
# Epoch 06580: ReduceLROnPlateau reducing learning rate to 5.499627891980552e-10.
#
# Epoch 06595: ReduceLROnPlateau reducing learning rate to 5.224646576484914e-10.
#
# Epoch 06610: ReduceLROnPlateau reducing learning rate to 4.963414484970841e-10.
#
# Epoch 06625: ReduceLROnPlateau reducing learning rate to 4.715243945296876e-10.
#
# Epoch 06640: ReduceLROnPlateau reducing learning rate to 4.4794815634574545e-10.
#
# Epoch 06655: ReduceLROnPlateau reducing learning rate to 4.255507432548988e-10.
#
# Epoch 06670: ReduceLROnPlateau reducing learning rate to 4.04273196863425e-10.
#
# Epoch 06685: ReduceLROnPlateau reducing learning rate to 3.8405953833864355e-10.
#
# Epoch 06700: ReduceLROnPlateau reducing learning rate to 3.648565574665419e-10.
#
# Epoch 06715: ReduceLROnPlateau reducing learning rate to 3.466137335483843e-10.
#
# Epoch 06730: ReduceLROnPlateau reducing learning rate to 3.292830508261346e-10.
#
# Epoch 06745: ReduceLROnPlateau reducing learning rate to 3.1281889301126854e-10.
#
# Epoch 06760: ReduceLROnPlateau reducing learning rate to 2.9717793781358636e-10.
#
# Epoch 06775: ReduceLROnPlateau reducing learning rate to 2.8231905147002575e-10.
#
# Epoch 06790: ReduceLROnPlateau reducing learning rate to 2.6820310417008384e-10.
#
# Epoch 06805: ReduceLROnPlateau reducing learning rate to 2.547929436880203e-10.
#
# Epoch 06820: ReduceLROnPlateau reducing learning rate to 2.4205328991167007e-10.
#
# Epoch 06835: ReduceLROnPlateau reducing learning rate to 2.299506293712561e-10.
#
# Epoch 06850: ReduceLROnPlateau reducing learning rate to 2.1845309658430344e-10.
#
# Epoch 06865: ReduceLROnPlateau reducing learning rate to 2.0753044768784257e-10.
#
# Epoch 06880: ReduceLROnPlateau reducing learning rate to 1.9715392859942504e-10.
#
# Epoch 06895: ReduceLROnPlateau reducing learning rate to 1.872962354654284e-10.
#
# Epoch 06910: ReduceLROnPlateau reducing learning rate to 1.7793142237376712e-10.
#
# Epoch 06925: ReduceLROnPlateau reducing learning rate to 1.690348486182991e-10.
#
# Epoch 06940: ReduceLROnPlateau reducing learning rate to 1.6058309959543491e-10.
#
# Epoch 06955: ReduceLROnPlateau reducing learning rate to 1.5255394725244287e-10.
#
# Epoch 06970: ReduceLROnPlateau reducing learning rate to 1.4492624461626136e-10.
#
# Epoch 06985: ReduceLROnPlateau reducing learning rate to 1.3767992579349907e-10.
#
# Epoch 07000: ReduceLROnPlateau reducing learning rate to 1.3079592686704443e-10.
#
# Epoch 07015: ReduceLROnPlateau reducing learning rate to 1.242561331604719e-10.
#
# Epoch 07030: ReduceLROnPlateau reducing learning rate to 1.180433265024483e-10.
#
# Epoch 07045: ReduceLROnPlateau reducing learning rate to 1.1214115885893605e-10.
#
# Epoch 07060: ReduceLROnPlateau reducing learning rate to 1.065340995975994e-10.
#
# Epoch 07075: ReduceLROnPlateau reducing learning rate to 1.0120739593610927e-10.
#
# Epoch 07090: ReduceLROnPlateau reducing learning rate to 9.614702679849873e-11.
#
# Epoch 07105: ReduceLROnPlateau reducing learning rate to 9.133967644736617e-11.
#
# Epoch 07120: ReduceLROnPlateau reducing learning rate to 8.67726949321801e-11.
#
# Epoch 07135: ReduceLROnPlateau reducing learning rate to 8.243405853758378e-11.
#
# Epoch 07150: ReduceLROnPlateau reducing learning rate to 7.831235659949698e-11.
#
# Epoch 07165: ReduceLROnPlateau reducing learning rate to 7.439673876952213e-11.
#
# Epoch 07180: ReduceLROnPlateau reducing learning rate to 7.067690183104602e-11.
#
# Epoch 07195: ReduceLROnPlateau reducing learning rate to 6.714305673949372e-11.
#
# Epoch 07210: ReduceLROnPlateau reducing learning rate to 6.378590225453173e-11.
#
# Epoch 07225: ReduceLROnPlateau reducing learning rate to 6.059660516422039e-11.
#
# Epoch 07240: ReduceLROnPlateau reducing learning rate to 5.756677391721698e-11.
#
# Epoch 07255: ReduceLROnPlateau reducing learning rate to 5.4688435550953594e-11.
#
# Epoch 07270: ReduceLROnPlateau reducing learning rate to 5.19540126198148e-11.
#
# Epoch 07285: ReduceLROnPlateau reducing learning rate to 4.9356313307213906e-11.
#
# Epoch 07300: ReduceLROnPlateau reducing learning rate to 4.688849846584686e-11.
#
# Epoch 07315: ReduceLROnPlateau reducing learning rate to 4.454407502574309e-11.
#
# Epoch 07330: ReduceLROnPlateau reducing learning rate to 4.2316872922443236e-11.
#
# Epoch 07345: ReduceLROnPlateau reducing learning rate to 4.0201028617126154e-11.
#
# Epoch 07360: ReduceLROnPlateau reducing learning rate to 3.819097850465969e-11.
#
# Epoch 07375: ReduceLROnPlateau reducing learning rate to 3.6281429249829245e-11.
#
# Epoch 07390: ReduceLROnPlateau reducing learning rate to 3.446735778733778e-11.
#
# Epoch 07405: ReduceLROnPlateau reducing learning rate to 3.2743991545958195e-11.
#
# Epoch 07420: ReduceLROnPlateau reducing learning rate to 3.1106791968660284e-11.
#
# Epoch 07435: ReduceLROnPlateau reducing learning rate to 2.955145121663616e-11.
#
# Epoch 07450: ReduceLROnPlateau reducing learning rate to 2.807387898540181e-11.
#
# Epoch 07465: ReduceLROnPlateau reducing learning rate to 2.66701843769368e-11.
#
# Epoch 07480: ReduceLROnPlateau reducing learning rate to 2.5336675899684247e-11.
#
# Epoch 07495: ReduceLROnPlateau reducing learning rate to 2.4069841692703207e-11.
#
# Epoch 07510: ReduceLROnPlateau reducing learning rate to 2.286634952566868e-11.
#
# Epoch 07525: ReduceLROnPlateau reducing learning rate to 2.1723031966985883e-11.
#
# Epoch 07540: ReduceLROnPlateau reducing learning rate to 2.0636879791841034e-11.
#
# Epoch 07555: ReduceLROnPlateau reducing learning rate to 1.9605035390252156e-11.
#
# Epoch 07570: ReduceLROnPlateau reducing learning rate to 1.8624782879145262e-11.
#
# Epoch 07585: ReduceLROnPlateau reducing learning rate to 1.7693543158392443e-11.
#
# Epoch 07600: ReduceLROnPlateau reducing learning rate to 1.680886567087536e-11.
#
# Epoch 07615: ReduceLROnPlateau reducing learning rate to 1.5968421810536036e-11.
#
# Epoch 07630: ReduceLROnPlateau reducing learning rate to 1.516999997841495e-11.
#
# Epoch 07645: ReduceLROnPlateau reducing learning rate to 1.4411500638689123e-11.
#
# Epoch 07660: ReduceLROnPlateau reducing learning rate to 1.3690925606754666e-11.
#
# Epoch 07675: ReduceLROnPlateau reducing learning rate to 1.3006379697214076e-11.
#
# Epoch 07690: ReduceLROnPlateau reducing learning rate to 1.235606083595242e-11.
#
# Epoch 07705: ReduceLROnPlateau reducing learning rate to 1.1738257588156386e-11.
#
# Epoch 07720: ReduceLROnPlateau reducing learning rate to 1.1151345038346028e-11.
#
# Epoch 07735: ReduceLROnPlateau reducing learning rate to 1.0593778198425551e-11.
#
# Epoch 07750: ReduceLROnPlateau reducing learning rate to 1.006408953570237e-11.
#
# Epoch 07765: ReduceLROnPlateau reducing learning rate to 9.560884852918838e-12.
#
# Epoch 07780: ReduceLROnPlateau reducing learning rate to 9.08284081627131e-12.
#
# Epoch 07795: ReduceLROnPlateau reducing learning rate to 8.628698363460919e-12.
#
# Epoch 07810: ReduceLROnPlateau reducing learning rate to 8.197263527687238e-12.
#
# Epoch 07825: ReduceLROnPlateau reducing learning rate to 7.787400021705414e-12.
#
# Epoch 07840: ReduceLROnPlateau reducing learning rate to 7.398030061819826e-12.
#
# Epoch 07855: ReduceLROnPlateau reducing learning rate to 7.028128599928518e-12.
#
# Epoch 07870: ReduceLROnPlateau reducing learning rate to 6.676722087532727e-12.
#
# Epoch 07885: ReduceLROnPlateau reducing learning rate to 6.342886003755932e-12.
#
# Epoch 07900: ReduceLROnPlateau reducing learning rate to 6.025741559369246e-12.
#
# Epoch 07915: ReduceLROnPlateau reducing learning rate to 5.7244544608009424e-12.
#
# Epoch 07930: ReduceLROnPlateau reducing learning rate to 5.438231614161848e-12.
#
# Epoch 07945: ReduceLROnPlateau reducing learning rate to 5.1663198892548666e-12.
#
# Epoch 07960: ReduceLROnPlateau reducing learning rate to 4.9080040595908535e-12.
#
# Epoch 07975: ReduceLROnPlateau reducing learning rate to 4.662603918410835e-12.
#
# Epoch 07990: ReduceLROnPlateau reducing learning rate to 4.429473866689182e-12.
#
# Epoch 08005: ReduceLROnPlateau reducing learning rate to 4.208000029155834e-12.
#
# Epoch 08020: ReduceLROnPlateau reducing learning rate to 3.997599842299471e-12.
#
# Epoch 08035: ReduceLROnPlateau reducing learning rate to 3.797719994383386e-12.
#
# Epoch 08050: ReduceLROnPlateau reducing learning rate to 3.607833953464534e-12.
#
# Epoch 08065: ReduceLROnPlateau reducing learning rate to 3.427442173391942e-12.
#
# Epoch 08080: ReduceLROnPlateau reducing learning rate to 3.256070033822583e-12.
#
# Epoch 08095: ReduceLROnPlateau reducing learning rate to 3.0932666042308986e-12.
#
# Epoch 08110: ReduceLROnPlateau reducing learning rate to 2.938603201919909e-12.
#
# Epoch 08125: ReduceLROnPlateau reducing learning rate to 2.79167298002439e-12.
#
# Epoch 08140: ReduceLROnPlateau reducing learning rate to 2.652089279523567e-12.
#
# Epoch 08155: ReduceLROnPlateau reducing learning rate to 2.5194848052474682e-12.
#
# Epoch 08170: ReduceLROnPlateau reducing learning rate to 2.3935105958848567e-12.
#
# Epoch 08185: ReduceLROnPlateau reducing learning rate to 2.2738349939911693e-12.
#
# Epoch 08200: ReduceLROnPlateau reducing learning rate to 2.1601432339916903e-12.
#
# Epoch 08215: ReduceLROnPlateau reducing learning rate to 2.0521360001926615e-12.
#
# Epoch 08230: ReduceLROnPlateau reducing learning rate to 1.9495292207828697e-12.
#
# Epoch 08245: ReduceLROnPlateau reducing learning rate to 1.8520528318431707e-12.
#
# Epoch 08260: ReduceLROnPlateau reducing learning rate to 1.75945015935125e-12.
#
# Epoch 08275: ReduceLROnPlateau reducing learning rate to 1.671477610184005e-12.
#
# Epoch 08290: ReduceLROnPlateau reducing learning rate to 1.5879037451246858e-12.
#
# Epoch 08305: ReduceLROnPlateau reducing learning rate to 1.5085085578684513e-12.
#
# Epoch 08320: ReduceLROnPlateau reducing learning rate to 1.433083166024751e-12.
#
# Epoch 08335: ReduceLROnPlateau reducing learning rate to 1.3614289871236722e-12.
#
# Epoch 08350: ReduceLROnPlateau reducing learning rate to 1.2933575326175283e-12.
#
# Epoch 08365: ReduceLROnPlateau reducing learning rate to 1.2286896868864138e-12.
#
# Epoch 08380: ReduceLROnPlateau reducing learning rate to 1.1672551922421726e-12.
#
# Epoch 08395: ReduceLROnPlateau reducing learning rate to 1.1088924429299844e-12.
#
# Epoch 08410: ReduceLROnPlateau reducing learning rate to 1.0534478671331282e-12.
#
# Epoch 08425: ReduceLROnPlateau reducing learning rate to 1.0007755149761544e-12.
#
# Epoch 08440: ReduceLROnPlateau reducing learning rate to 9.507367495272673e-13.
#
# Epoch 08455: ReduceLROnPlateau reducing learning rate to 9.031999378007055e-13.
#
# Epoch 08470: ReduceLROnPlateau reducing learning rate to 8.580399357607099e-13.
#
# Epoch 08485: ReduceLROnPlateau reducing learning rate to 8.151379338227141e-13.
#
# Epoch 08500: ReduceLROnPlateau reducing learning rate to 7.743810448565188e-13.
#
# Epoch 08515: ReduceLROnPlateau reducing learning rate to 7.35661995188673e-13.
#
# Epoch 08530: ReduceLROnPlateau reducing learning rate to 6.988789186040608e-13.
#
# Epoch 08545: ReduceLROnPlateau reducing learning rate to 6.639349958486792e-13.
#
# Epoch 08560: ReduceLROnPlateau reducing learning rate to 6.307382486312254e-13.
#
# Epoch 08575: ReduceLROnPlateau reducing learning rate to 5.99201333624684e-13.
#
# Epoch 08590: ReduceLROnPlateau reducing learning rate to 5.692412849683109e-13.
#
# Epoch 08605: ReduceLROnPlateau reducing learning rate to 5.407792052700144e-13.
#
# Epoch 08620: ReduceLROnPlateau reducing learning rate to 5.13740265606355e-13.
#
# Epoch 08635: ReduceLROnPlateau reducing learning rate to 4.880532420261166e-13.
#
# Epoch 08650: ReduceLROnPlateau reducing learning rate to 4.6365056704991e-13.
#
# Epoch 08665: ReduceLROnPlateau reducing learning rate to 4.4046802067255334e-13.
#
# Epoch 08680: ReduceLROnPlateau reducing learning rate to 4.1844462736386613e-13.
#
# Epoch 08695: ReduceLROnPlateau reducing learning rate to 3.97522398570653e-13.
#
# Epoch 08710: ReduceLROnPlateau reducing learning rate to 3.776462812171005e-13.
#
# Epoch 08725: ReduceLROnPlateau reducing learning rate to 3.587639774561661e-13.
#
# Epoch 08740: ReduceLROnPlateau reducing learning rate to 3.4082579017076856e-13.
#
# Epoch 08755: ReduceLROnPlateau reducing learning rate to 3.2378449422477974e-13.
#
# Epoch 08770: ReduceLROnPlateau reducing learning rate to 3.0759525921362007e-13.
#
# Epoch 08785: ReduceLROnPlateau reducing learning rate to 2.9221549496544903e-13.
#
# Epoch 08800: ReduceLROnPlateau reducing learning rate to 2.776047227921567e-13.
#
# Epoch 08815: ReduceLROnPlateau reducing learning rate to 2.637244982399596e-13.
#
# Epoch 08830: ReduceLROnPlateau reducing learning rate to 2.505382823403922e-13.
#
# Epoch 08845: ReduceLROnPlateau reducing learning rate to 2.380113643609023e-13.
#
# Epoch 08860: ReduceLROnPlateau reducing learning rate to 2.261107845554465e-13.
#
# Epoch 08875: ReduceLROnPlateau reducing learning rate to 2.148052440401841e-13.
#
# Epoch 08890: ReduceLROnPlateau reducing learning rate to 2.0406497604446952e-13.
#
# Epoch 08905: ReduceLROnPlateau reducing learning rate to 1.938617330359514e-13.
#
# Epoch 08920: ReduceLROnPlateau reducing learning rate to 1.8416864509666376e-13.
#
# Epoch 08935: ReduceLROnPlateau reducing learning rate to 1.749602070481252e-13.
#
# Epoch 08950: ReduceLROnPlateau reducing learning rate to 1.6621220120193424e-13.
#
# Epoch 08965: ReduceLROnPlateau reducing learning rate to 1.5790159436056271e-13.
#
# Epoch 08980: ReduceLROnPlateau reducing learning rate to 1.5000651206755442e-13.
#
# Epoch 08995: ReduceLROnPlateau reducing learning rate to 1.4250618710792175e-13.
#
# Epoch 09010: ReduceLROnPlateau reducing learning rate to 1.3538088225874093e-13.
#
# Epoch 09025: ReduceLROnPlateau reducing learning rate to 1.2861183878954892e-13.
#
# Epoch 09040: ReduceLROnPlateau reducing learning rate to 1.221812507125417e-13.
#
# Epoch 09055: ReduceLROnPlateau reducing learning rate to 1.160721875331696e-13.
#
# Epoch 09070: ReduceLROnPlateau reducing learning rate to 1.1026858137523631e-13.
#
# Epoch 09085: ReduceLROnPlateau reducing learning rate to 1.0475514973149434e-13.
#
# Epoch 09100: ReduceLROnPlateau reducing learning rate to 9.951739546364482e-14.
#
# Epoch 09115: ReduceLROnPlateau reducing learning rate to 9.454152311548242e-14.
#
# Epoch 09130: ReduceLROnPlateau reducing learning rate to 8.98144453503457e-14.
#
# Epoch 09145: ReduceLROnPlateau reducing learning rate to 8.532372501406354e-14.
#
# Epoch 09160: ReduceLROnPlateau reducing learning rate to 8.105753651025271e-14.
#
# Epoch 09175: ReduceLROnPlateau reducing learning rate to 7.700465936286756e-14.
#
# Epoch 09190: ReduceLROnPlateau reducing learning rate to 7.315442671659671e-14.
#
# Epoch 09205: ReduceLROnPlateau reducing learning rate to 6.949670602451191e-14.
#
# Epoch 09220: ReduceLROnPlateau reducing learning rate to 6.602187329826647e-14.
#
# Epoch 09235: ReduceLROnPlateau reducing learning rate to 6.272078092084322e-14.
#
# Epoch 09250: ReduceLROnPlateau reducing learning rate to 5.958474477165374e-14.
#
# Epoch 09265: ReduceLROnPlateau reducing learning rate to 5.660550560183594e-14.
#
# Epoch 09280: ReduceLROnPlateau reducing learning rate to 5.377522903425406e-14.
#
# Epoch 09295: ReduceLROnPlateau reducing learning rate to 5.108646693879632e-14.
#
# Epoch 09310: ReduceLROnPlateau reducing learning rate to 4.853214455747406e-14.
#
# Epoch 09325: ReduceLROnPlateau reducing learning rate to 4.61055379733454e-14.
#
# Epoch 09340: ReduceLROnPlateau reducing learning rate to 4.380026123561439e-14.
#
# Epoch 09355: ReduceLROnPlateau reducing learning rate to 4.161024704727985e-14.
#
# Epoch 09370: ReduceLROnPlateau reducing learning rate to 3.952973389023456e-14.
#
# Epoch 09385: ReduceLROnPlateau reducing learning rate to 3.755324671291405e-14.
#
# Epoch 09400: ReduceLROnPlateau reducing learning rate to 3.567558405539583e-14.
#
# Epoch 09415: ReduceLROnPlateau reducing learning rate to 3.3891805174498555e-14.
#
# Epoch 09430: ReduceLROnPlateau reducing learning rate to 3.219721395015607e-14.
#
# Epoch 09445: ReduceLROnPlateau reducing learning rate to 3.058735244796697e-14.
#
# Epoch 09460: ReduceLROnPlateau reducing learning rate to 2.905798482556862e-14.
#
# Epoch 09475: ReduceLROnPlateau reducing learning rate to 2.7605084457736367e-14.
#
# Epoch 09490: ReduceLROnPlateau reducing learning rate to 2.6224830717658328e-14.
#
# Epoch 09505: ReduceLROnPlateau reducing learning rate to 2.4913589664584192e-14.
#
# Epoch 09520: ReduceLROnPlateau reducing learning rate to 2.3667910825100023e-14.
#
# Epoch 09535: ReduceLROnPlateau reducing learning rate to 2.248451592759006e-14.
#
# Epoch 09550: ReduceLROnPlateau reducing learning rate to 2.1360290855423728e-14.
#
# Epoch 09565: ReduceLROnPlateau reducing learning rate to 2.0292275990780023e-14.
#
# Epoch 09580: ReduceLROnPlateau reducing learning rate to 1.927766299592232e-14.
#
# Epoch 09595: ReduceLROnPlateau reducing learning rate to 1.8313780328934983e-14.
#
# Epoch 09610: ReduceLROnPlateau reducing learning rate to 1.7398091634360755e-14.
#
# Epoch 09625: ReduceLROnPlateau reducing learning rate to 1.6528187696387757e-14.
#
# Epoch 09640: ReduceLROnPlateau reducing learning rate to 1.57017783920365e-14.
#
# Epoch 09655: ReduceLROnPlateau reducing learning rate to 1.4916689472434673e-14.
#
# Epoch 09670: ReduceLROnPlateau reducing learning rate to 1.4170854516004161e-14.
#
# Epoch 09685: ReduceLROnPlateau reducing learning rate to 1.3462311709735822e-14.
#
# Epoch 09700: ReduceLROnPlateau reducing learning rate to 1.2789195802376511e-14.
#
# Epoch 09715: ReduceLROnPlateau reducing learning rate to 1.2149735690385165e-14.
#
# Epoch 09730: ReduceLROnPlateau reducing learning rate to 1.1542248785163713e-14.
#
# Epoch 09745: ReduceLROnPlateau reducing learning rate to 1.0965136184969266e-14.
#
# Epoch 09760: ReduceLROnPlateau reducing learning rate to 1.0416879456188934e-14.
#
# Epoch 09775: ReduceLROnPlateau reducing learning rate to 9.896035805252007e-15.
#
# Epoch 09790: ReduceLROnPlateau reducing learning rate to 9.401234055223472e-15.
#
# Epoch 09805: ReduceLROnPlateau reducing learning rate to 8.931172231760103e-15.
#
# Epoch 09820: ReduceLROnPlateau reducing learning rate to 8.484613539703969e-15.
#
# Epoch 09835: ReduceLROnPlateau reducing learning rate to 8.060383144357224e-15.
#
# Epoch 09850: ReduceLROnPlateau reducing learning rate to 7.657364148075623e-15.
#
# Epoch 09865: ReduceLROnPlateau reducing learning rate to 7.274495980905907e-15.
#
# Epoch 09880: ReduceLROnPlateau reducing learning rate to 6.910771181860612e-15.
#
# Epoch 09895: ReduceLROnPlateau reducing learning rate to 6.565232582533516e-15.
#
# Epoch 09910: ReduceLROnPlateau reducing learning rate to 6.2369708930557425e-15.
#
# Epoch 09925: ReduceLROnPlateau reducing learning rate to 5.925122288051858e-15.
#
# Epoch 09940: ReduceLROnPlateau reducing learning rate to 5.628865992595973e-15.
#
# Epoch 09955: ReduceLROnPlateau reducing learning rate to 5.3474226728491415e-15.
#
# Epoch 09970: ReduceLROnPlateau reducing learning rate to 5.080051619674815e-15.
#
# Epoch 09985: ReduceLROnPlateau reducing learning rate to 4.8260491392762364e-15.
#
# Epoch 10000: ReduceLROnPlateau reducing learning rate to 4.584746541493197e-15.

# %%
 ''' show the history of the current model '''
train_rmse = np.array(result['history'].history['root_mean_squared_error'])
dev_rmse = np.array(result['history'].history['val_root_mean_squared_error'])

import matplotlib.pyplot as plt
plt.figure()
plt.plot(range(len(train_rmse)),train_rmse,'-')
plt.plot(range(len(dev_rmse)),dev_rmse,'-')
plt.plot(np.argmin(dev_rmse),np.min(dev_rmse),'r*')
plt.text(np.argmin(dev_rmse)+50,np.min(dev_rmse)+50,str(np.min(dev_rmse)))
# Out:
# Text(3974, 281.2553253173828, '231.2553253173828')

# %%
 ''' show the history of the current model '''
R2 = np.array(result['history'].history['R2'])
val_R2 = np.array(result['history'].history['val_R2'])

import matplotlib.pyplot as plt
plt.figure()
plt.plot(range(len(R2)),R2,'-')
plt.plot(range(len(val_R2)),val_R2,'-')
plt.plot(np.argmax(val_R2),np.max(val_R2),'r*')
plt.text(np.argmax(val_R2)-0.3,np.max(val_R2)-0.3,str(np.max(val_R2)))
# Out:
# Text(3923.7, 0.6105756282806396, '0.9105756282806396')

# %% [markdown]
# # validation

# %%
''' validation '''
bestModel = result['bestModel']
train_part,dev_part = result['train_dev_set']

# %%
train_fea = train_part[:,:-1]
train_tar = train_part[:,-1]
dev_fea = dev_part[:,:-1]
dev_tar = dev_part[:,-1]

# %%
''' customizing metric R2 '''
def R2(y_true, y_pred):
  if type(y_true) == 'numpy.ndarray':
    y_true = tf.constant(y_true)
    y_pred = tf.constant(y_pred)
  flat_ture = tf.reshape(y_true, [-1])
  flat_prd = tf.reshape(y_pred, [-1])
  RSS = tf.math.reduce_sum((tf.math.square(flat_ture - flat_prd)),axis=-1)
  TSS = tf.math.reduce_sum(tf.math.square(flat_ture - tf.reduce_mean(flat_ture,axis=-1)))
  return 1-RSS/TSS

# %%
R2(train_tar.astype(float),bestModel.predict(train_fea).astype(float))
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.9693022994647164>

# %%
R2(dev_tar.astype(float), bestModel.predict(dev_fea).astype(float))
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.9105756654938242>

# %%
whole_fea = np.concatenate((train_fea,dev_fea))
whole_tar = np.concatenate((train_tar,dev_tar))

R2(whole_tar.astype(float), bestModel.predict(whole_fea).astype(float))
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.9532982042652063>

# %%
plt.figure()
ax = plt.hist(whole_tar, bins=100, facecolor="blue", edgecolor="black", alpha=0.7)

# %%
plt.figure()
ax = plt.hist( bestModel.predict(whole_fea).astype(float), bins=100, facecolor="blue", edgecolor="black", alpha=0.7)

# %%
plt.scatter(whole_tar,bestModel.predict(whole_fea).astype(float))

# %% [markdown]
# # save results

# %%
''' save model and parameters '''
result['bestModel'].save('bestModel.h5')
pd.DataFrame(result['history'].history).to_csv('history.csv')
np.save('train_arr.npy',result['train_dev_set'][0])
np.save('dev_arr.npy',result['train_dev_set'][1])
from joblib import dump, load
dump(result['normalizer'],'scaler.joblib')
