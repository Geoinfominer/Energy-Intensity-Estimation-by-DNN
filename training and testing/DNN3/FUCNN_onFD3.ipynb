# %% [markdown]
# # this notebook was initially run on Google Colab

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Jan 27 03:14:28 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # import libraries

# %%
'''
import libraries
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Model
from tensorflow.keras.optimizers import Adam
import os
import random
random.seed(0)
tf.random.set_seed(0)
np.random.seed(0)
os.environ['PYTHONHASHSEED'] = str(0)

# %% [markdown]
# # define variables

# %%
features = ['lucc_0','lucc_1','lucc_2','lucc_3','lucc_4','lucc_5','b1','b2','b3','b4','b5','b6','b7','lst','ndvi','ntl','elevation','entropy','max_x','max_y','min_x','min_y']
GeoFeas = ['lucc_0','lucc_1','lucc_2','lucc_3','lucc_4','lucc_5','b1','b2','b3','b4','b5','b6','b7','lst','ndvi','ntl','elevation','entropy']
CoordFeas = ['max_x','max_y','min_x','min_y']
years = list(range(2001,2018))
provs30 = ['Qinghai','Guizhou','Guangxi','Xinjiang','Chongqing','Jilin','Sichuan','Hubei','Beijing',
      'Liaoning','Heilongjiang','Shandong','Guangdong','Hebei','Henan','Hainan','Ningxia',
      'Gansu','Neimenggu','Tianjin','Shanxi_jin','Yunnan','Fujian','Jiangxi','Anhui',
      'Hunan','Jiangsu','Zhejiang','Shanghai','Shanxi_qin']
dir_csv = '/boot/'

# %% [markdown]
# # read data and preprocess

# %%
'''
read one fold(we use 4-fold cross validation)
'''
trainDf = pd.read_csv('/boot/fd3_TrainData.csv')
devDf = pd.read_csv('/boot/fd3_TestData.csv')

# %%
''' convert into numpy '''
def convert_fromDF_toNP(full_df_):
  full_arr_ = full_df_[GeoFeas+['ei1000']].to_numpy()
  return full_arr_

# %%
train_arr = convert_fromDF_toNP(trainDf)
dev_arr = convert_fromDF_toNP(devDf)

# %%
# show the distribution of the dev_arr dataset
plt.figure(figsize=(30,40))
for i in range(19): 
    ax = plt.subplot(7, 7, i + 1)
    plt.hist(dev_arr[:,i],bins=40)
    plt.title(devDf.columns[i+2])

# %%
''' normalization '''
def normalize_features(train_part,dev_part):
  ''' !DON'T normalize ei1000 '''
  ''' !DON'T normalize ei1000 '''
  ''' !DON'T normalize ei1000 '''
  '''
  train_part and dev_part are numpy arr.
  '''
  # fit normalizer
  '''
  from sklearn.preprocessing import MinMaxScaler
  scaler = MinMaxScaler()
  scaler.fit(train_part[:,:-1])
  '''
  
  from sklearn.preprocessing import PowerTransformer
  scaler = PowerTransformer(method='yeo-johnson')
  scaler.fit(train_part[:,:-1])
  
  '''
  from sklearn.preprocessing import QuantileTransformer 
  scaler = QuantileTransformer(n_quantiles=len(train_part),output_distribution='normal', random_state=0) 
  scaler.fit(train_part[:,:-1])
  '''
  # transform
  train_part[:,:-1] = scaler.transform(train_part[:,:-1])
  dev_part[:,:-1] = scaler.transform(dev_part[:,:-1])

  return train_part,dev_part,scaler

# %%
train_arr,dev_arr,scaler = normalize_features(train_arr,dev_arr)

# %%
# show the distribution of the dev_part
plt.figure(figsize=(30,40))
for i in range(19): 
    ax = plt.subplot(7, 7, i + 1)
    plt.hist(dev_arr[:,i],bins=40)
    plt.title(devDf.columns[i+2])

# %%
''' convert into tf.data.Dataset '''
def generateTFDataset(arr):
  ''' arr contains features and labels '''
  ds = tf.data.Dataset.from_tensor_slices(arr)
  ds = ds.map(lambda ts:(ts[:-1],ts[-1]))
  ds = ds.shuffle(510)
  ds = ds.batch(510)
  return ds

# %%
ds_train = generateTFDataset(train_arr)
ds_dev = generateTFDataset(dev_arr)

# %% [markdown]
# # define model

# %%
''' build model '''
def create_model(input_shape):
  ''' input_shape,say,is (18,)  '''
  # set seed=0 in the weight initializer
  weight_init = tf.keras.initializers.GlorotUniform(seed = 0)

  # input layer: corresponding to embedding matrix
  x_input = keras.layers.Input(shape = input_shape)

  # model body
  x = keras.layers.Dense(32,activation = "relu", kernel_initializer=weight_init)(x_input)
  x = keras.layers.Dense(32,activation = "relu", kernel_initializer=weight_init)(x)
  x = keras.layers.Dense(16,activation = "relu", kernel_initializer=weight_init)(x)
  x = keras.layers.Dense(8,activation = "relu", kernel_initializer=weight_init)(x)
  x = keras.layers.Dense(8,activation = "relu", kernel_initializer=weight_init)(x)
  x = keras.layers.Dense(1,activation = "relu", kernel_initializer=weight_init)(x)

  # summary
  model = Model(inputs = x_input, outputs = x)
  return model

# %%
''' customizing metric R2 '''
def R2(y_true, y_pred):
  if type(y_true) == 'numpy.ndarray':
    y_true = tf.constant(y_true)
    y_pred = tf.constant(y_pred)
  flat_ture = tf.reshape(y_true, [-1])
  flat_prd = tf.reshape(y_pred, [-1])
  RSS = tf.math.reduce_sum((tf.math.square(flat_ture - flat_prd)),axis=-1)
  TSS = tf.math.reduce_sum(tf.math.square(flat_ture - tf.reduce_mean(flat_ture,axis=-1)))
  return 1-RSS/TSS

# %% [markdown]
# # run model

# %%
''' run model '''
def run_model(train_df_ = None, dev_df_ = None,lr_ = None,epo = None,checkpoint_path=None):

  # convert into numpy
  print('convert into numpy... ...')
  train_arr = convert_fromDF_toNP(train_df_)
  dev_arr = convert_fromDF_toNP(dev_df_)

  # normalization
  print('normalization... ...')
  train_arr,dev_arr,scaler = normalize_features(train_arr,dev_arr)

  # convert into tf.data.Dataset
  print('convert into tf.data.Dataset... ...')
  ds_train = generateTFDataset(train_arr)
  ds_dev = generateTFDataset(dev_arr)

  # build model
  print('build model... ...')
  model = create_model(train_arr.shape[1]-1)

  # compile model
  print('compile model... ...')
  opt = Adam(lr=lr_) 
  model.compile(loss=tf.keras.losses.MeanSquaredError(), 
         optimizer=opt, 
         metrics=[tf.keras.metrics.RootMeanSquaredError(),R2])
  model.summary()
  cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,save_best_only=True, save_weights_only=True, verbose=0)
  reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                           factor=0.95, 
                           patience=15, 
                           verbose=1)

  # fit model
  history = model.fit(
        ds_train,
        epochs=epo,
        validation_data=ds_dev,
        callbacks=[cp_callback,reduce_lr],
        verbose = 0)
  
  # reload best_model
  bestModel = create_model(train_arr.shape[1]-1)
  bestModel.compile(loss=tf.keras.losses.MeanSquaredError(), 
           optimizer=opt, 
           metrics=[tf.keras.metrics.RootMeanSquaredError(),R2])
  bestModel.load_weights(checkpoint_path)

  # return best_model and parameters
  return {
      'bestModel' : bestModel,
      'history' : history,
      'train_dev_set' : (train_arr,dev_arr),
      'normalizer' : scaler
      }

# %%
result = run_model(
          train_df_ = trainDf, dev_df_ = devDf,
          lr_ = 0.001,
          epo = 10000,
          checkpoint_path='/boot/cp.best.ckpt'
          )
# Out:
# convert into numpy... ...
# normalization... ...
# convert into tf.data.Dataset... ...
# build model... ...
# compile model... ...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 18)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                608
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_21 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_22 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 2,409
# Trainable params: 2,409
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 01501: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
#
# Epoch 01520: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
#
# Epoch 01567: ReduceLROnPlateau reducing learning rate to 0.0008573750033974647.
#
# Epoch 01582: ReduceLROnPlateau reducing learning rate to 0.0008145062311086804.
#
# Epoch 01597: ReduceLROnPlateau reducing learning rate to 0.0007737808919046074.
#
# Epoch 01612: ReduceLROnPlateau reducing learning rate to 0.000735091819660738.
#
# Epoch 01627: ReduceLROnPlateau reducing learning rate to 0.0006983372120885178.
#
# Epoch 01642: ReduceLROnPlateau reducing learning rate to 0.0006634203542489559.
#
# Epoch 01657: ReduceLROnPlateau reducing learning rate to 0.0006302493420662358.
#
# Epoch 01672: ReduceLROnPlateau reducing learning rate to 0.0005987368611386045.
#
# Epoch 01687: ReduceLROnPlateau reducing learning rate to 0.0005688000208465382.
#
# Epoch 01702: ReduceLROnPlateau reducing learning rate to 0.0005403600225690752.
#
# Epoch 01717: ReduceLROnPlateau reducing learning rate to 0.0005133419937919825.
#
# Epoch 01732: ReduceLROnPlateau reducing learning rate to 0.0004876748775132.
#
# Epoch 01747: ReduceLROnPlateau reducing learning rate to 0.00046329112810781223.
#
# Epoch 01762: ReduceLROnPlateau reducing learning rate to 0.00044012657308485355.
#
# Epoch 01777: ReduceLROnPlateau reducing learning rate to 0.00041812024719547477.
#
# Epoch 01792: ReduceLROnPlateau reducing learning rate to 0.00039721422654110934.
#
# Epoch 01807: ReduceLROnPlateau reducing learning rate to 0.00037735351797891776.
#
# Epoch 01822: ReduceLROnPlateau reducing learning rate to 0.00035848583793267607.
#
# Epoch 01837: ReduceLROnPlateau reducing learning rate to 0.00034056155709549785.
#
# Epoch 01852: ReduceLROnPlateau reducing learning rate to 0.00032353347924072293.
#
# Epoch 01867: ReduceLROnPlateau reducing learning rate to 0.00030735681357327847.
#
# Epoch 01882: ReduceLROnPlateau reducing learning rate to 0.00029198898118920624.
#
# Epoch 01897: ReduceLROnPlateau reducing learning rate to 0.00027738953212974593.
#
# Epoch 01912: ReduceLROnPlateau reducing learning rate to 0.0002635200624354184.
#
# Epoch 01927: ReduceLROnPlateau reducing learning rate to 0.0002503440482541919.
#
# Epoch 01942: ReduceLROnPlateau reducing learning rate to 0.00023782684584148226.
#
# Epoch 01957: ReduceLROnPlateau reducing learning rate to 0.00022593549801968037.
#
# Epoch 01972: ReduceLROnPlateau reducing learning rate to 0.00021463872035383245.
#
# Epoch 01987: ReduceLROnPlateau reducing learning rate to 0.0002039067905570846.
#
# Epoch 02002: ReduceLROnPlateau reducing learning rate to 0.00019371145172044634.
#
# Epoch 02017: ReduceLROnPlateau reducing learning rate to 0.00018402588466415182.
#
# Epoch 02032: ReduceLROnPlateau reducing learning rate to 0.00017482458351878447.
#
# Epoch 02047: ReduceLROnPlateau reducing learning rate to 0.0001660833557252772.
#
# Epoch 02062: ReduceLROnPlateau reducing learning rate to 0.0001577791837917175.
#
# Epoch 02077: ReduceLROnPlateau reducing learning rate to 0.0001498902252933476.
#
# Epoch 02092: ReduceLROnPlateau reducing learning rate to 0.00014239571610232815.
#
# Epoch 02107: ReduceLROnPlateau reducing learning rate to 0.00013527592891477978.
#
# Epoch 02122: ReduceLROnPlateau reducing learning rate to 0.00012851213177782482.
#
# Epoch 02137: ReduceLROnPlateau reducing learning rate to 0.00012208651896798982.
#
# Epoch 02152: ReduceLROnPlateau reducing learning rate to 0.00011598219716688617.
#
# Epoch 02167: ReduceLROnPlateau reducing learning rate to 0.00011018308869097381.
#
# Epoch 02182: ReduceLROnPlateau reducing learning rate to 0.00010467393149156123.
#
# Epoch 02197: ReduceLROnPlateau reducing learning rate to 9.944023768184706e-05.
#
# Epoch 02212: ReduceLROnPlateau reducing learning rate to 9.446822441532275e-05.
#
# Epoch 02227: ReduceLROnPlateau reducing learning rate to 8.974481388577259e-05.
#
# Epoch 02242: ReduceLROnPlateau reducing learning rate to 8.525757111783605e-05.
#
# Epoch 02257: ReduceLROnPlateau reducing learning rate to 8.099469014268834e-05.
#
# Epoch 02272: ReduceLROnPlateau reducing learning rate to 7.694495252508204e-05.
#
# Epoch 02287: ReduceLROnPlateau reducing learning rate to 7.309770662686787e-05.
#
# Epoch 02302: ReduceLROnPlateau reducing learning rate to 6.944281922187656e-05.
#
# Epoch 02317: ReduceLROnPlateau reducing learning rate to 6.597067549591884e-05.
#
# Epoch 02332: ReduceLROnPlateau reducing learning rate to 6.267214448598679e-05.
#
# Epoch 02347: ReduceLROnPlateau reducing learning rate to 5.953853760729544e-05.
#
# Epoch 02362: ReduceLROnPlateau reducing learning rate to 5.656161210936261e-05.
#
# Epoch 02377: ReduceLROnPlateau reducing learning rate to 5.373353305913042e-05.
#
# Epoch 02392: ReduceLROnPlateau reducing learning rate to 5.104685606056591e-05.
#
# Epoch 02407: ReduceLROnPlateau reducing learning rate to 4.849451343034161e-05.
#
# Epoch 02422: ReduceLROnPlateau reducing learning rate to 4.606978654919658e-05.
#
# Epoch 02437: ReduceLROnPlateau reducing learning rate to 4.3766295493696814e-05.
#
# Epoch 02452: ReduceLROnPlateau reducing learning rate to 4.1577981755835934e-05.
#
# Epoch 02467: ReduceLROnPlateau reducing learning rate to 3.949908405047608e-05.
#
# Epoch 02482: ReduceLROnPlateau reducing learning rate to 3.752413140318822e-05.
#
# Epoch 02497: ReduceLROnPlateau reducing learning rate to 3.564792586985277e-05.
#
# Epoch 02512: ReduceLROnPlateau reducing learning rate to 3.3865528712340166e-05.
#
# Epoch 02527: ReduceLROnPlateau reducing learning rate to 3.217225348635111e-05.
#
# Epoch 02542: ReduceLROnPlateau reducing learning rate to 3.0563641848857516e-05.
#
# Epoch 02557: ReduceLROnPlateau reducing learning rate to 2.9035460102022626e-05.
#
# Epoch 02572: ReduceLROnPlateau reducing learning rate to 2.7583687096921494e-05.
#
# Epoch 02587: ReduceLROnPlateau reducing learning rate to 2.620450213726144e-05.
#
# Epoch 02602: ReduceLROnPlateau reducing learning rate to 2.4894276339182395e-05.
#
# Epoch 02617: ReduceLROnPlateau reducing learning rate to 2.3649562263017287e-05.
#
# Epoch 02632: ReduceLROnPlateau reducing learning rate to 2.2467083545052444e-05.
#
# Epoch 02647: ReduceLROnPlateau reducing learning rate to 2.134372971340781e-05.
#
# Epoch 02662: ReduceLROnPlateau reducing learning rate to 2.0276544091757387e-05.
#
# Epoch 02677: ReduceLROnPlateau reducing learning rate to 1.9262716887169517e-05.
#
# Epoch 02692: ReduceLROnPlateau reducing learning rate to 1.8299581734027014e-05.
#
# Epoch 02707: ReduceLROnPlateau reducing learning rate to 1.7384601869707693e-05.
#
# Epoch 02722: ReduceLROnPlateau reducing learning rate to 1.6515371862624305e-05.
#
# Epoch 02737: ReduceLROnPlateau reducing learning rate to 1.568960378790507e-05.
#
# Epoch 02752: ReduceLROnPlateau reducing learning rate to 1.490512377131381e-05.
#
# Epoch 02767: ReduceLROnPlateau reducing learning rate to 1.4159867669150115e-05.
#
# Epoch 02782: ReduceLROnPlateau reducing learning rate to 1.3451874156089615e-05.
#
# Epoch 02797: ReduceLROnPlateau reducing learning rate to 1.2779280405084136e-05.
#
# Epoch 02812: ReduceLROnPlateau reducing learning rate to 1.2140316039221942e-05.
#
# Epoch 02827: ReduceLROnPlateau reducing learning rate to 1.1533300539667834e-05.
#
# Epoch 02842: ReduceLROnPlateau reducing learning rate to 1.0956635469483444e-05.
#
# Epoch 02857: ReduceLROnPlateau reducing learning rate to 1.0408803609607275e-05.
#
# Epoch 02872: ReduceLROnPlateau reducing learning rate to 9.888363774734898e-06.
#
# Epoch 02887: ReduceLROnPlateau reducing learning rate to 9.393945629199151e-06.
#
# Epoch 02902: ReduceLROnPlateau reducing learning rate to 8.92424795893021e-06.
#
# Epoch 02917: ReduceLROnPlateau reducing learning rate to 8.478035215375711e-06.
#
# Epoch 02932: ReduceLROnPlateau reducing learning rate to 8.054133195400936e-06.
#
# Epoch 02947: ReduceLROnPlateau reducing learning rate to 7.651426449228893e-06.
#
# Epoch 02962: ReduceLROnPlateau reducing learning rate to 7.2688548243604595e-06.
#
# Epoch 02977: ReduceLROnPlateau reducing learning rate to 6.905412169544433e-06.
#
# Epoch 02992: ReduceLROnPlateau reducing learning rate to 6.5601415826677105e-06.
#
# Epoch 03007: ReduceLROnPlateau reducing learning rate to 6.2321345467353235e-06.
#
# Epoch 03022: ReduceLROnPlateau reducing learning rate to 5.920527905800554e-06.
#
# Epoch 03037: ReduceLROnPlateau reducing learning rate to 5.624501704915019e-06.
#
# Epoch 03052: ReduceLROnPlateau reducing learning rate to 5.343276598068769e-06.
#
# Epoch 03067: ReduceLROnPlateau reducing learning rate to 5.076112984170322e-06.
#
# Epoch 03082: ReduceLROnPlateau reducing learning rate to 4.8223071189568145e-06.
#
# Epoch 03097: ReduceLROnPlateau reducing learning rate to 4.581191979013965e-06.
#
# Epoch 03112: ReduceLROnPlateau reducing learning rate to 4.352132509666262e-06.
#
# Epoch 03127: ReduceLROnPlateau reducing learning rate to 4.134526056986942e-06.
#
# Epoch 03142: ReduceLROnPlateau reducing learning rate to 3.927799775738094e-06.
#
# Epoch 03157: ReduceLROnPlateau reducing learning rate to 3.7314097653506904e-06.
#
# Epoch 03172: ReduceLROnPlateau reducing learning rate to 3.5448393418846533e-06.
#
# Epoch 03187: ReduceLROnPlateau reducing learning rate to 3.3675973099889233e-06.
#
# Epoch 03202: ReduceLROnPlateau reducing learning rate to 3.199217530891474e-06.
#
# Epoch 03217: ReduceLROnPlateau reducing learning rate to 3.039256762349396e-06.
#
# Epoch 03232: ReduceLROnPlateau reducing learning rate to 2.887294010633923e-06.
#
# Epoch 03247: ReduceLROnPlateau reducing learning rate to 2.7429292345004796e-06.
#
# Epoch 03262: ReduceLROnPlateau reducing learning rate to 2.6057826971737086e-06.
#
# Epoch 03277: ReduceLROnPlateau reducing learning rate to 2.4754936703175187e-06.
#
# Epoch 03292: ReduceLROnPlateau reducing learning rate to 2.3517189220001454e-06.
#
# Epoch 03307: ReduceLROnPlateau reducing learning rate to 2.2341329326991397e-06.
#
# Epoch 03322: ReduceLROnPlateau reducing learning rate to 2.122426383266429e-06.
#
# Epoch 03337: ReduceLROnPlateau reducing learning rate to 2.0163050749033573e-06.
#
# Epoch 03352: ReduceLROnPlateau reducing learning rate to 1.915489929160685e-06.
#
# Epoch 03367: ReduceLROnPlateau reducing learning rate to 1.8197154759036493e-06.
#
# Epoch 03382: ReduceLROnPlateau reducing learning rate to 1.728729745309465e-06.
#
# Epoch 03397: ReduceLROnPlateau reducing learning rate to 1.6422932958448655e-06.
#
# Epoch 03412: ReduceLROnPlateau reducing learning rate to 1.5601786742536206e-06.
#
# Epoch 03427: ReduceLROnPlateau reducing learning rate to 1.4821697675415633e-06.
#
# Epoch 03442: ReduceLROnPlateau reducing learning rate to 1.408061262964111e-06.
#
# Epoch 03457: ReduceLROnPlateau reducing learning rate to 1.3376582160162797e-06.
#
# Epoch 03472: ReduceLROnPlateau reducing learning rate to 1.2707752944152161e-06.
#
# Epoch 03487: ReduceLROnPlateau reducing learning rate to 1.207236562095204e-06.
#
# Epoch 03502: ReduceLROnPlateau reducing learning rate to 1.1468747231901943e-06.
#
# Epoch 03517: ReduceLROnPlateau reducing learning rate to 1.0895310140313086e-06.
#
# Epoch 03532: ReduceLROnPlateau reducing learning rate to 1.0350544471293687e-06.
#
# Epoch 03547: ReduceLROnPlateau reducing learning rate to 9.833017031724012e-07.
#
# Epoch 03562: ReduceLROnPlateau reducing learning rate to 9.341365910131571e-07.
#
# Epoch 03577: ReduceLROnPlateau reducing learning rate to 8.874297776628737e-07.
#
# Epoch 03592: ReduceLROnPlateau reducing learning rate to 8.43058302280042e-07.
#
# Epoch 03607: ReduceLROnPlateau reducing learning rate to 8.009053601654159e-07.
#
# Epoch 03622: ReduceLROnPlateau reducing learning rate to 7.608600867570203e-07.
#
# Epoch 03637: ReduceLROnPlateau reducing learning rate to 7.228170716189196e-07.
#
# Epoch 03652: ReduceLROnPlateau reducing learning rate to 6.866761964374745e-07.
#
# Epoch 03667: ReduceLROnPlateau reducing learning rate to 6.523423650151017e-07.
#
# Epoch 03682: ReduceLROnPlateau reducing learning rate to 6.197252332640346e-07.
#
# Epoch 03697: ReduceLROnPlateau reducing learning rate to 5.887389932013321e-07.
#
# Epoch 03712: ReduceLROnPlateau reducing learning rate to 5.593020489413902e-07.
#
# Epoch 03727: ReduceLROnPlateau reducing learning rate to 5.313369626946951e-07.
#
# Epoch 03742: ReduceLROnPlateau reducing learning rate to 5.047701307603347e-07.
#
# Epoch 03757: ReduceLROnPlateau reducing learning rate to 4.795316215222556e-07.
#
# Epoch 03772: ReduceLROnPlateau reducing learning rate to 4.5555506744676677e-07.
#
# Epoch 03787: ReduceLROnPlateau reducing learning rate to 4.327773140744284e-07.
#
# Epoch 03802: ReduceLROnPlateau reducing learning rate to 4.111384470206758e-07.
#
# Epoch 03817: ReduceLROnPlateau reducing learning rate to 3.905815219695796e-07.
#
# Epoch 03832: ReduceLROnPlateau reducing learning rate to 3.710524566713502e-07.
#
# Epoch 03847: ReduceLROnPlateau reducing learning rate to 3.524998419379699e-07.
#
# Epoch 03862: ReduceLROnPlateau reducing learning rate to 3.3487486064132097e-07.
#
# Epoch 03877: ReduceLROnPlateau reducing learning rate to 3.1813112570944214e-07.
#
# Epoch 03892: ReduceLROnPlateau reducing learning rate to 3.022245721240324e-07.
#
# Epoch 03907: ReduceLROnPlateau reducing learning rate to 2.871133489179556e-07.
#
# Epoch 03922: ReduceLROnPlateau reducing learning rate to 2.727576841721202e-07.
#
# Epoch 03937: ReduceLROnPlateau reducing learning rate to 2.591198040136078e-07.
#
# Epoch 03952: ReduceLROnPlateau reducing learning rate to 2.46163824613177e-07.
#
# Epoch 03967: ReduceLROnPlateau reducing learning rate to 2.3385564418276772e-07.
#
# Epoch 03982: ReduceLROnPlateau reducing learning rate to 2.2216286197362933e-07.
#
# Epoch 03997: ReduceLROnPlateau reducing learning rate to 2.1105472427507264e-07.
#
# Epoch 04012: ReduceLROnPlateau reducing learning rate to 2.005019894113502e-07.
#
# Epoch 04027: ReduceLROnPlateau reducing learning rate to 1.904768872407203e-07.
#
# Epoch 04042: ReduceLROnPlateau reducing learning rate to 1.809530381535751e-07.
#
# Epoch 04057: ReduceLROnPlateau reducing learning rate to 1.7190538557088075e-07.
#
# Epoch 04072: ReduceLROnPlateau reducing learning rate to 1.633101149423055e-07.
#
# Epoch 04087: ReduceLROnPlateau reducing learning rate to 1.5514461324528383e-07.
#
# Epoch 04102: ReduceLROnPlateau reducing learning rate to 1.4738738798314444e-07.
#
# Epoch 04117: ReduceLROnPlateau reducing learning rate to 1.4001801318386242e-07.
#
# Epoch 04132: ReduceLROnPlateau reducing learning rate to 1.330171158997473e-07.
#
# Epoch 04147: ReduceLROnPlateau reducing learning rate to 1.2636625470463514e-07.
#
# Epoch 04162: ReduceLROnPlateau reducing learning rate to 1.2004794669451258e-07.
#
# Epoch 04177: ReduceLROnPlateau reducing learning rate to 1.1404554598470895e-07.
#
# Epoch 04192: ReduceLROnPlateau reducing learning rate to 1.0834327071052029e-07.
#
# Epoch 04207: ReduceLROnPlateau reducing learning rate to 1.0292610852502548e-07.
#
# Epoch 04222: ReduceLROnPlateau reducing learning rate to 9.77798030987742e-08.
#
# Epoch 04237: ReduceLROnPlateau reducing learning rate to 9.289081361885109e-08.
#
# Epoch 04252: ReduceLROnPlateau reducing learning rate to 8.824627428793974e-08.
#
# Epoch 04267: ReduceLROnPlateau reducing learning rate to 8.383396057354275e-08.
#
# Epoch 04282: ReduceLROnPlateau reducing learning rate to 7.964226220735781e-08.
#
# Epoch 04297: ReduceLROnPlateau reducing learning rate to 7.566014943449773e-08.
#
# Epoch 04312: ReduceLROnPlateau reducing learning rate to 7.187713926271044e-08.
#
# Epoch 04327: ReduceLROnPlateau reducing learning rate to 6.828328196206712e-08.
#
# Epoch 04342: ReduceLROnPlateau reducing learning rate to 6.486912056402616e-08.
#
# Epoch 04357: ReduceLROnPlateau reducing learning rate to 6.162566386080926e-08.
#
# Epoch 04372: ReduceLROnPlateau reducing learning rate to 5.854437965524539e-08.
#
# Epoch 04387: ReduceLROnPlateau reducing learning rate to 5.561716100999092e-08.
#
# Epoch 04402: ReduceLROnPlateau reducing learning rate to 5.2836302621983573e-08.
#
# Epoch 04417: ReduceLROnPlateau reducing learning rate to 5.0194487322130494e-08.
#
# Epoch 04432: ReduceLROnPlateau reducing learning rate to 4.768476244976227e-08.
#
# Epoch 04447: ReduceLROnPlateau reducing learning rate to 4.530052297724296e-08.
#
# Epoch 04462: ReduceLROnPlateau reducing learning rate to 4.303549800965811e-08.
#
# Epoch 04477: ReduceLROnPlateau reducing learning rate to 4.0883723784190804e-08.
#
# Epoch 04492: ReduceLROnPlateau reducing learning rate to 3.883953691996567e-08.
#
# Epoch 04507: ReduceLROnPlateau reducing learning rate to 3.689756091773688e-08.
#
# Epoch 04522: ReduceLROnPlateau reducing learning rate to 3.505268253434224e-08.
#
# Epoch 04537: ReduceLROnPlateau reducing learning rate to 3.3300048407625126e-08.
#
# Epoch 04552: ReduceLROnPlateau reducing learning rate to 3.163504480596657e-08.
#
# Epoch 04567: ReduceLROnPlateau reducing learning rate to 3.005329425320724e-08.
#
# Epoch 04582: ReduceLROnPlateau reducing learning rate to 2.855062852802348e-08.
#
# Epoch 04597: ReduceLROnPlateau reducing learning rate to 2.7123097101622307e-08.
#
# Epoch 04612: ReduceLROnPlateau reducing learning rate to 2.576694182465644e-08.
#
# Epoch 04627: ReduceLROnPlateau reducing learning rate to 2.4478595239685317e-08.
#
# Epoch 04642: ReduceLROnPlateau reducing learning rate to 2.32546653933241e-08.
#
# Epoch 04657: ReduceLROnPlateau reducing learning rate to 2.2091932461165697e-08.
#
# Epoch 04672: ReduceLROnPlateau reducing learning rate to 2.0987335247468764e-08.
#
# Epoch 04687: ReduceLROnPlateau reducing learning rate to 1.9937967810079724e-08.
#
# Epoch 04702: ReduceLROnPlateau reducing learning rate to 1.894106933519879e-08.
#
# Epoch 04717: ReduceLROnPlateau reducing learning rate to 1.799401569968495e-08.
#
# Epoch 04732: ReduceLROnPlateau reducing learning rate to 1.7094314408439004e-08.
#
# Epoch 04747: ReduceLROnPlateau reducing learning rate to 1.623959953178655e-08.
#
# Epoch 04762: ReduceLROnPlateau reducing learning rate to 1.5427619892705025e-08.
#
# Epoch 04777: ReduceLROnPlateau reducing learning rate to 1.4656239066823672e-08.
#
# Epoch 04792: ReduceLROnPlateau reducing learning rate to 1.392342694472859e-08.
#
# Epoch 04807: ReduceLROnPlateau reducing learning rate to 1.322725551311521e-08.
#
# Epoch 04822: ReduceLROnPlateau reducing learning rate to 1.2565892948401824e-08.
#
# Epoch 04837: ReduceLROnPlateau reducing learning rate to 1.1937598554112583e-08.
#
# Epoch 04852: ReduceLROnPlateau reducing learning rate to 1.1340718542030003e-08.
#
# Epoch 04867: ReduceLROnPlateau reducing learning rate to 1.0773682657116978e-08.
#
# Epoch 04882: ReduceLROnPlateau reducing learning rate to 1.023499827113028e-08.
#
# Epoch 04897: ReduceLROnPlateau reducing learning rate to 9.723248695081565e-09.
#
# Epoch 04912: ReduceLROnPlateau reducing learning rate to 9.237086429081387e-09.
#
# Epoch 04927: ReduceLROnPlateau reducing learning rate to 8.775232318569692e-09.
#
# Epoch 04942: ReduceLROnPlateau reducing learning rate to 8.336470491698833e-09.
#
# Epoch 04957: ReduceLROnPlateau reducing learning rate to 7.919646671794566e-09.
#
# Epoch 04972: ReduceLROnPlateau reducing learning rate to 7.523663958508563e-09.
#
# Epoch 04987: ReduceLROnPlateau reducing learning rate to 7.14748114027941e-09.
#
# Epoch 05002: ReduceLROnPlateau reducing learning rate to 6.790107209830864e-09.
#
# Epoch 05017: ReduceLROnPlateau reducing learning rate to 6.450601786056608e-09.
#
# Epoch 05032: ReduceLROnPlateau reducing learning rate to 6.128071738942253e-09.
#
# Epoch 05047: ReduceLROnPlateau reducing learning rate to 5.82166823637209e-09.
#
# Epoch 05062: ReduceLROnPlateau reducing learning rate to 5.5305846347053486e-09.
#
# Epoch 05077: ReduceLROnPlateau reducing learning rate to 5.254055213121944e-09.
#
# Epoch 05092: ReduceLROnPlateau reducing learning rate to 4.991352642313984e-09.
#
# Epoch 05107: ReduceLROnPlateau reducing learning rate to 4.741785031292523e-09.
#
# Epoch 05122: ReduceLROnPlateau reducing learning rate to 4.504695927387558e-09.
#
# Epoch 05137: ReduceLROnPlateau reducing learning rate to 4.279460941170043e-09.
#
# Epoch 05152: ReduceLROnPlateau reducing learning rate to 4.0654877464518786e-09.
#
# Epoch 05167: ReduceLROnPlateau reducing learning rate to 3.862213548977422e-09.
#
# Epoch 05182: ReduceLROnPlateau reducing learning rate to 3.6691029769997383e-09.
#
# Epoch 05197: ReduceLROnPlateau reducing learning rate to 3.4856478703382264e-09.
#
# Epoch 05212: ReduceLROnPlateau reducing learning rate to 3.3113653818972463e-09.
#
# Epoch 05227: ReduceLROnPlateau reducing learning rate to 3.1457971338966215e-09.
#
# Epoch 05242: ReduceLROnPlateau reducing learning rate to 2.9885073193902654e-09.
#
# Epoch 05257: ReduceLROnPlateau reducing learning rate to 2.8390818584966837e-09.
#
# Epoch 05272: ReduceLROnPlateau reducing learning rate to 2.6971277655718494e-09.
#
# Epoch 05287: ReduceLROnPlateau reducing learning rate to 2.5622714616702067e-09.
#
# Epoch 05302: ReduceLROnPlateau reducing learning rate to 2.4341579307751715e-09.
#
# Epoch 05317: ReduceLROnPlateau reducing learning rate to 2.3124500869720065e-09.
#
# Epoch 05332: ReduceLROnPlateau reducing learning rate to 2.196827508793575e-09.
#
# Epoch 05347: ReduceLROnPlateau reducing learning rate to 2.086986228277965e-09.
#
# Epoch 05362: ReduceLROnPlateau reducing learning rate to 1.982636832487117e-09.
#
# Epoch 05377: ReduceLROnPlateau reducing learning rate to 1.8835048853915738e-09.
#
# Epoch 05392: ReduceLROnPlateau reducing learning rate to 1.7893296622162323e-09.
#
# Epoch 05407: ReduceLROnPlateau reducing learning rate to 1.6998632001996582e-09.
#
# Epoch 05422: ReduceLROnPlateau reducing learning rate to 1.6148700876517095e-09.
#
# Epoch 05437: ReduceLROnPlateau reducing learning rate to 1.5341266201840396e-09.
#
# Epoch 05452: ReduceLROnPlateau reducing learning rate to 1.4574202733541596e-09.
#
# Epoch 05467: ReduceLROnPlateau reducing learning rate to 1.3845492807806892e-09.
#
# Epoch 05482: ReduceLROnPlateau reducing learning rate to 1.3153217903738578e-09.
#
# Epoch 05497: ReduceLROnPlateau reducing learning rate to 1.2495556533931307e-09.
#
# Epoch 05512: ReduceLROnPlateau reducing learning rate to 1.187077897091271e-09.
#
# Epoch 05527: ReduceLROnPlateau reducing learning rate to 1.1277239864160294e-09.
#
# Epoch 05542: ReduceLROnPlateau reducing learning rate to 1.0713378240101434e-09.
#
# Epoch 05557: ReduceLROnPlateau reducing learning rate to 1.0177709064418394e-09.
#
# Epoch 05572: ReduceLROnPlateau reducing learning rate to 9.668823242048319e-10.
#
# Epoch 05587: ReduceLROnPlateau reducing learning rate to 9.185382343623871e-10.
#
# Epoch 05602: ReduceLROnPlateau reducing learning rate to 8.726113331913864e-10.
#
# Epoch 05617: ReduceLROnPlateau reducing learning rate to 8.289807507111391e-10.
#
# Epoch 05632: ReduceLROnPlateau reducing learning rate to 7.875317342698196e-10.
#
# Epoch 05647: ReduceLROnPlateau reducing learning rate to 7.481551211885318e-10.
#
# Epoch 05662: ReduceLROnPlateau reducing learning rate to 7.107473387613083e-10.
#
# Epoch 05677: ReduceLROnPlateau reducing learning rate to 6.752099823703616e-10.
#
# Epoch 05692: ReduceLROnPlateau reducing learning rate to 6.414494990725217e-10.
#
# Epoch 05707: ReduceLROnPlateau reducing learning rate to 6.09377029392455e-10.
#
# Epoch 05722: ReduceLROnPlateau reducing learning rate to 5.7890819638029e-10.
#
# Epoch 05737: ReduceLROnPlateau reducing learning rate to 5.499627891980552e-10.
#
# Epoch 05752: ReduceLROnPlateau reducing learning rate to 5.224646576484914e-10.
#
# Epoch 05767: ReduceLROnPlateau reducing learning rate to 4.963414484970841e-10.
#
# Epoch 05782: ReduceLROnPlateau reducing learning rate to 4.715243945296876e-10.
#
# Epoch 05797: ReduceLROnPlateau reducing learning rate to 4.4794815634574545e-10.
#
# Epoch 05812: ReduceLROnPlateau reducing learning rate to 4.255507432548988e-10.
#
# Epoch 05827: ReduceLROnPlateau reducing learning rate to 4.04273196863425e-10.
#
# Epoch 05842: ReduceLROnPlateau reducing learning rate to 3.8405953833864355e-10.
#
# Epoch 05857: ReduceLROnPlateau reducing learning rate to 3.648565574665419e-10.
#
# Epoch 05872: ReduceLROnPlateau reducing learning rate to 3.466137335483843e-10.
#
# Epoch 05887: ReduceLROnPlateau reducing learning rate to 3.292830508261346e-10.
#
# Epoch 05902: ReduceLROnPlateau reducing learning rate to 3.1281889301126854e-10.
#
# Epoch 05917: ReduceLROnPlateau reducing learning rate to 2.9717793781358636e-10.
#
# Epoch 05932: ReduceLROnPlateau reducing learning rate to 2.8231905147002575e-10.
#
# Epoch 05947: ReduceLROnPlateau reducing learning rate to 2.6820310417008384e-10.
#
# Epoch 05962: ReduceLROnPlateau reducing learning rate to 2.547929436880203e-10.
#
# Epoch 05977: ReduceLROnPlateau reducing learning rate to 2.4205328991167007e-10.
#
# Epoch 05992: ReduceLROnPlateau reducing learning rate to 2.299506293712561e-10.
#
# Epoch 06007: ReduceLROnPlateau reducing learning rate to 2.1845309658430344e-10.
#
# Epoch 06022: ReduceLROnPlateau reducing learning rate to 2.0753044768784257e-10.
#
# Epoch 06037: ReduceLROnPlateau reducing learning rate to 1.9715392859942504e-10.
#
# Epoch 06052: ReduceLROnPlateau reducing learning rate to 1.872962354654284e-10.
#
# Epoch 06067: ReduceLROnPlateau reducing learning rate to 1.7793142237376712e-10.
#
# Epoch 06082: ReduceLROnPlateau reducing learning rate to 1.690348486182991e-10.
#
# Epoch 06097: ReduceLROnPlateau reducing learning rate to 1.6058309959543491e-10.
#
# Epoch 06112: ReduceLROnPlateau reducing learning rate to 1.5255394725244287e-10.
#
# Epoch 06127: ReduceLROnPlateau reducing learning rate to 1.4492624461626136e-10.
#
# Epoch 06142: ReduceLROnPlateau reducing learning rate to 1.3767992579349907e-10.
#
# Epoch 06157: ReduceLROnPlateau reducing learning rate to 1.3079592686704443e-10.
#
# Epoch 06172: ReduceLROnPlateau reducing learning rate to 1.242561331604719e-10.
#
# Epoch 06187: ReduceLROnPlateau reducing learning rate to 1.180433265024483e-10.
#
# Epoch 06202: ReduceLROnPlateau reducing learning rate to 1.1214115885893605e-10.
#
# Epoch 06217: ReduceLROnPlateau reducing learning rate to 1.065340995975994e-10.
#
# Epoch 06232: ReduceLROnPlateau reducing learning rate to 1.0120739593610927e-10.
#
# Epoch 06247: ReduceLROnPlateau reducing learning rate to 9.614702679849873e-11.
#
# Epoch 06262: ReduceLROnPlateau reducing learning rate to 9.133967644736617e-11.
#
# Epoch 06277: ReduceLROnPlateau reducing learning rate to 8.67726949321801e-11.
#
# Epoch 06292: ReduceLROnPlateau reducing learning rate to 8.243405853758378e-11.
#
# Epoch 06307: ReduceLROnPlateau reducing learning rate to 7.831235659949698e-11.
#
# Epoch 06322: ReduceLROnPlateau reducing learning rate to 7.439673876952213e-11.
#
# Epoch 06337: ReduceLROnPlateau reducing learning rate to 7.067690183104602e-11.
#
# Epoch 06352: ReduceLROnPlateau reducing learning rate to 6.714305673949372e-11.
#
# Epoch 06367: ReduceLROnPlateau reducing learning rate to 6.378590225453173e-11.
#
# Epoch 06382: ReduceLROnPlateau reducing learning rate to 6.059660516422039e-11.
#
# Epoch 06397: ReduceLROnPlateau reducing learning rate to 5.756677391721698e-11.
#
# Epoch 06412: ReduceLROnPlateau reducing learning rate to 5.4688435550953594e-11.
#
# Epoch 06427: ReduceLROnPlateau reducing learning rate to 5.19540126198148e-11.
#
# Epoch 06442: ReduceLROnPlateau reducing learning rate to 4.9356313307213906e-11.
#
# Epoch 06457: ReduceLROnPlateau reducing learning rate to 4.688849846584686e-11.
#
# Epoch 06472: ReduceLROnPlateau reducing learning rate to 4.454407502574309e-11.
#
# Epoch 06487: ReduceLROnPlateau reducing learning rate to 4.2316872922443236e-11.
#
# Epoch 06502: ReduceLROnPlateau reducing learning rate to 4.0201028617126154e-11.
#
# Epoch 06517: ReduceLROnPlateau reducing learning rate to 3.819097850465969e-11.
#
# Epoch 06532: ReduceLROnPlateau reducing learning rate to 3.6281429249829245e-11.
#
# Epoch 06547: ReduceLROnPlateau reducing learning rate to 3.446735778733778e-11.
#
# Epoch 06562: ReduceLROnPlateau reducing learning rate to 3.2743991545958195e-11.
#
# Epoch 06577: ReduceLROnPlateau reducing learning rate to 3.1106791968660284e-11.
#
# Epoch 06592: ReduceLROnPlateau reducing learning rate to 2.955145121663616e-11.
#
# Epoch 06607: ReduceLROnPlateau reducing learning rate to 2.807387898540181e-11.
#
# Epoch 06622: ReduceLROnPlateau reducing learning rate to 2.66701843769368e-11.
#
# Epoch 06637: ReduceLROnPlateau reducing learning rate to 2.5336675899684247e-11.
#
# Epoch 06652: ReduceLROnPlateau reducing learning rate to 2.4069841692703207e-11.
#
# Epoch 06667: ReduceLROnPlateau reducing learning rate to 2.286634952566868e-11.
#
# Epoch 06682: ReduceLROnPlateau reducing learning rate to 2.1723031966985883e-11.
#
# Epoch 06697: ReduceLROnPlateau reducing learning rate to 2.0636879791841034e-11.
#
# Epoch 06712: ReduceLROnPlateau reducing learning rate to 1.9605035390252156e-11.
#
# Epoch 06727: ReduceLROnPlateau reducing learning rate to 1.8624782879145262e-11.
#
# Epoch 06742: ReduceLROnPlateau reducing learning rate to 1.7693543158392443e-11.
#
# Epoch 06757: ReduceLROnPlateau reducing learning rate to 1.680886567087536e-11.
#
# Epoch 06772: ReduceLROnPlateau reducing learning rate to 1.5968421810536036e-11.
#
# Epoch 06787: ReduceLROnPlateau reducing learning rate to 1.516999997841495e-11.
#
# Epoch 06802: ReduceLROnPlateau reducing learning rate to 1.4411500638689123e-11.
#
# Epoch 06817: ReduceLROnPlateau reducing learning rate to 1.3690925606754666e-11.
#
# Epoch 06832: ReduceLROnPlateau reducing learning rate to 1.3006379697214076e-11.
#
# Epoch 06847: ReduceLROnPlateau reducing learning rate to 1.235606083595242e-11.
#
# Epoch 06862: ReduceLROnPlateau reducing learning rate to 1.1738257588156386e-11.
#
# Epoch 06877: ReduceLROnPlateau reducing learning rate to 1.1151345038346028e-11.
#
# Epoch 06892: ReduceLROnPlateau reducing learning rate to 1.0593778198425551e-11.
#
# Epoch 06907: ReduceLROnPlateau reducing learning rate to 1.006408953570237e-11.
#
# Epoch 06922: ReduceLROnPlateau reducing learning rate to 9.560884852918838e-12.
#
# Epoch 06937: ReduceLROnPlateau reducing learning rate to 9.08284081627131e-12.
#
# Epoch 06952: ReduceLROnPlateau reducing learning rate to 8.628698363460919e-12.
#
# Epoch 06967: ReduceLROnPlateau reducing learning rate to 8.197263527687238e-12.
#
# Epoch 06982: ReduceLROnPlateau reducing learning rate to 7.787400021705414e-12.
#
# Epoch 06997: ReduceLROnPlateau reducing learning rate to 7.398030061819826e-12.
#
# Epoch 07012: ReduceLROnPlateau reducing learning rate to 7.028128599928518e-12.
#
# Epoch 07027: ReduceLROnPlateau reducing learning rate to 6.676722087532727e-12.
#
# Epoch 07042: ReduceLROnPlateau reducing learning rate to 6.342886003755932e-12.
#
# Epoch 07057: ReduceLROnPlateau reducing learning rate to 6.025741559369246e-12.
#
# Epoch 07072: ReduceLROnPlateau reducing learning rate to 5.7244544608009424e-12.
#
# Epoch 07087: ReduceLROnPlateau reducing learning rate to 5.438231614161848e-12.
#
# Epoch 07102: ReduceLROnPlateau reducing learning rate to 5.1663198892548666e-12.
#
# Epoch 07117: ReduceLROnPlateau reducing learning rate to 4.9080040595908535e-12.
#
# Epoch 07132: ReduceLROnPlateau reducing learning rate to 4.662603918410835e-12.
#
# Epoch 07147: ReduceLROnPlateau reducing learning rate to 4.429473866689182e-12.
#
# Epoch 07162: ReduceLROnPlateau reducing learning rate to 4.208000029155834e-12.
#
# Epoch 07177: ReduceLROnPlateau reducing learning rate to 3.997599842299471e-12.
#
# Epoch 07192: ReduceLROnPlateau reducing learning rate to 3.797719994383386e-12.
#
# Epoch 07207: ReduceLROnPlateau reducing learning rate to 3.607833953464534e-12.
#
# Epoch 07222: ReduceLROnPlateau reducing learning rate to 3.427442173391942e-12.
#
# Epoch 07237: ReduceLROnPlateau reducing learning rate to 3.256070033822583e-12.
#
# Epoch 07252: ReduceLROnPlateau reducing learning rate to 3.0932666042308986e-12.
#
# Epoch 07267: ReduceLROnPlateau reducing learning rate to 2.938603201919909e-12.
#
# Epoch 07282: ReduceLROnPlateau reducing learning rate to 2.79167298002439e-12.
#
# Epoch 07297: ReduceLROnPlateau reducing learning rate to 2.652089279523567e-12.
#
# Epoch 07312: ReduceLROnPlateau reducing learning rate to 2.5194848052474682e-12.
#
# Epoch 07327: ReduceLROnPlateau reducing learning rate to 2.3935105958848567e-12.
#
# Epoch 07342: ReduceLROnPlateau reducing learning rate to 2.2738349939911693e-12.
#
# Epoch 07357: ReduceLROnPlateau reducing learning rate to 2.1601432339916903e-12.
#
# Epoch 07372: ReduceLROnPlateau reducing learning rate to 2.0521360001926615e-12.
#
# Epoch 07387: ReduceLROnPlateau reducing learning rate to 1.9495292207828697e-12.
#
# Epoch 07402: ReduceLROnPlateau reducing learning rate to 1.8520528318431707e-12.
#
# Epoch 07417: ReduceLROnPlateau reducing learning rate to 1.75945015935125e-12.
#
# Epoch 07432: ReduceLROnPlateau reducing learning rate to 1.671477610184005e-12.
#
# Epoch 07447: ReduceLROnPlateau reducing learning rate to 1.5879037451246858e-12.
#
# Epoch 07462: ReduceLROnPlateau reducing learning rate to 1.5085085578684513e-12.
#
# Epoch 07477: ReduceLROnPlateau reducing learning rate to 1.433083166024751e-12.
#
# Epoch 07492: ReduceLROnPlateau reducing learning rate to 1.3614289871236722e-12.
#
# Epoch 07507: ReduceLROnPlateau reducing learning rate to 1.2933575326175283e-12.
#
# Epoch 07522: ReduceLROnPlateau reducing learning rate to 1.2286896868864138e-12.
#
# Epoch 07537: ReduceLROnPlateau reducing learning rate to 1.1672551922421726e-12.
#
# Epoch 07552: ReduceLROnPlateau reducing learning rate to 1.1088924429299844e-12.
#
# Epoch 07567: ReduceLROnPlateau reducing learning rate to 1.0534478671331282e-12.
#
# Epoch 07582: ReduceLROnPlateau reducing learning rate to 1.0007755149761544e-12.
#
# Epoch 07597: ReduceLROnPlateau reducing learning rate to 9.507367495272673e-13.
#
# Epoch 07612: ReduceLROnPlateau reducing learning rate to 9.031999378007055e-13.
#
# Epoch 07627: ReduceLROnPlateau reducing learning rate to 8.580399357607099e-13.
#
# Epoch 07642: ReduceLROnPlateau reducing learning rate to 8.151379338227141e-13.
#
# Epoch 07657: ReduceLROnPlateau reducing learning rate to 7.743810448565188e-13.
#
# Epoch 07672: ReduceLROnPlateau reducing learning rate to 7.35661995188673e-13.
#
# Epoch 07687: ReduceLROnPlateau reducing learning rate to 6.988789186040608e-13.
#
# Epoch 07702: ReduceLROnPlateau reducing learning rate to 6.639349958486792e-13.
#
# Epoch 07717: ReduceLROnPlateau reducing learning rate to 6.307382486312254e-13.
#
# Epoch 07732: ReduceLROnPlateau reducing learning rate to 5.99201333624684e-13.
#
# Epoch 07747: ReduceLROnPlateau reducing learning rate to 5.692412849683109e-13.
#
# Epoch 07762: ReduceLROnPlateau reducing learning rate to 5.407792052700144e-13.
#
# Epoch 07777: ReduceLROnPlateau reducing learning rate to 5.13740265606355e-13.
#
# Epoch 07792: ReduceLROnPlateau reducing learning rate to 4.880532420261166e-13.
#
# Epoch 07807: ReduceLROnPlateau reducing learning rate to 4.6365056704991e-13.
#
# Epoch 07822: ReduceLROnPlateau reducing learning rate to 4.4046802067255334e-13.
#
# Epoch 07837: ReduceLROnPlateau reducing learning rate to 4.1844462736386613e-13.
#
# Epoch 07852: ReduceLROnPlateau reducing learning rate to 3.97522398570653e-13.
#
# Epoch 07867: ReduceLROnPlateau reducing learning rate to 3.776462812171005e-13.
#
# Epoch 07882: ReduceLROnPlateau reducing learning rate to 3.587639774561661e-13.
#
# Epoch 07897: ReduceLROnPlateau reducing learning rate to 3.4082579017076856e-13.
#
# Epoch 07912: ReduceLROnPlateau reducing learning rate to 3.2378449422477974e-13.
#
# Epoch 07927: ReduceLROnPlateau reducing learning rate to 3.0759525921362007e-13.
#
# Epoch 07942: ReduceLROnPlateau reducing learning rate to 2.9221549496544903e-13.
#
# Epoch 07957: ReduceLROnPlateau reducing learning rate to 2.776047227921567e-13.
#
# Epoch 07972: ReduceLROnPlateau reducing learning rate to 2.637244982399596e-13.
#
# Epoch 07987: ReduceLROnPlateau reducing learning rate to 2.505382823403922e-13.
#
# Epoch 08002: ReduceLROnPlateau reducing learning rate to 2.380113643609023e-13.
#
# Epoch 08017: ReduceLROnPlateau reducing learning rate to 2.261107845554465e-13.
#
# Epoch 08032: ReduceLROnPlateau reducing learning rate to 2.148052440401841e-13.
#
# Epoch 08047: ReduceLROnPlateau reducing learning rate to 2.0406497604446952e-13.
#
# Epoch 08062: ReduceLROnPlateau reducing learning rate to 1.938617330359514e-13.
#
# Epoch 08077: ReduceLROnPlateau reducing learning rate to 1.8416864509666376e-13.
#
# Epoch 08092: ReduceLROnPlateau reducing learning rate to 1.749602070481252e-13.
#
# Epoch 08107: ReduceLROnPlateau reducing learning rate to 1.6621220120193424e-13.
#
# Epoch 08122: ReduceLROnPlateau reducing learning rate to 1.5790159436056271e-13.
#
# Epoch 08137: ReduceLROnPlateau reducing learning rate to 1.5000651206755442e-13.
#
# Epoch 08152: ReduceLROnPlateau reducing learning rate to 1.4250618710792175e-13.
#
# Epoch 08167: ReduceLROnPlateau reducing learning rate to 1.3538088225874093e-13.
#
# Epoch 08182: ReduceLROnPlateau reducing learning rate to 1.2861183878954892e-13.
#
# Epoch 08197: ReduceLROnPlateau reducing learning rate to 1.221812507125417e-13.
#
# Epoch 08212: ReduceLROnPlateau reducing learning rate to 1.160721875331696e-13.
#
# Epoch 08227: ReduceLROnPlateau reducing learning rate to 1.1026858137523631e-13.
#
# Epoch 08242: ReduceLROnPlateau reducing learning rate to 1.0475514973149434e-13.
#
# Epoch 08257: ReduceLROnPlateau reducing learning rate to 9.951739546364482e-14.
#
# Epoch 08272: ReduceLROnPlateau reducing learning rate to 9.454152311548242e-14.
#
# Epoch 08287: ReduceLROnPlateau reducing learning rate to 8.98144453503457e-14.
#
# Epoch 08302: ReduceLROnPlateau reducing learning rate to 8.532372501406354e-14.
#
# Epoch 08317: ReduceLROnPlateau reducing learning rate to 8.105753651025271e-14.
#
# Epoch 08332: ReduceLROnPlateau reducing learning rate to 7.700465936286756e-14.
#
# Epoch 08347: ReduceLROnPlateau reducing learning rate to 7.315442671659671e-14.
#
# Epoch 08362: ReduceLROnPlateau reducing learning rate to 6.949670602451191e-14.
#
# Epoch 08377: ReduceLROnPlateau reducing learning rate to 6.602187329826647e-14.
#
# Epoch 08392: ReduceLROnPlateau reducing learning rate to 6.272078092084322e-14.
#
# Epoch 08407: ReduceLROnPlateau reducing learning rate to 5.958474477165374e-14.
#
# Epoch 08422: ReduceLROnPlateau reducing learning rate to 5.660550560183594e-14.
#
# Epoch 08437: ReduceLROnPlateau reducing learning rate to 5.377522903425406e-14.
#
# Epoch 08452: ReduceLROnPlateau reducing learning rate to 5.108646693879632e-14.
#
# Epoch 08467: ReduceLROnPlateau reducing learning rate to 4.853214455747406e-14.
#
# Epoch 08482: ReduceLROnPlateau reducing learning rate to 4.61055379733454e-14.
#
# Epoch 08497: ReduceLROnPlateau reducing learning rate to 4.380026123561439e-14.
#
# Epoch 08512: ReduceLROnPlateau reducing learning rate to 4.161024704727985e-14.
#
# Epoch 08527: ReduceLROnPlateau reducing learning rate to 3.952973389023456e-14.
#
# Epoch 08542: ReduceLROnPlateau reducing learning rate to 3.755324671291405e-14.
#
# Epoch 08557: ReduceLROnPlateau reducing learning rate to 3.567558405539583e-14.
#
# Epoch 08572: ReduceLROnPlateau reducing learning rate to 3.3891805174498555e-14.
#
# Epoch 08587: ReduceLROnPlateau reducing learning rate to 3.219721395015607e-14.
#
# Epoch 08602: ReduceLROnPlateau reducing learning rate to 3.058735244796697e-14.
#
# Epoch 08617: ReduceLROnPlateau reducing learning rate to 2.905798482556862e-14.
#
# Epoch 08632: ReduceLROnPlateau reducing learning rate to 2.7605084457736367e-14.
#
# Epoch 08647: ReduceLROnPlateau reducing learning rate to 2.6224830717658328e-14.
#
# Epoch 08662: ReduceLROnPlateau reducing learning rate to 2.4913589664584192e-14.
#
# Epoch 08677: ReduceLROnPlateau reducing learning rate to 2.3667910825100023e-14.
#
# Epoch 08692: ReduceLROnPlateau reducing learning rate to 2.248451592759006e-14.
#
# Epoch 08707: ReduceLROnPlateau reducing learning rate to 2.1360290855423728e-14.
#
# Epoch 08722: ReduceLROnPlateau reducing learning rate to 2.0292275990780023e-14.
#
# Epoch 08737: ReduceLROnPlateau reducing learning rate to 1.927766299592232e-14.
#
# Epoch 08752: ReduceLROnPlateau reducing learning rate to 1.8313780328934983e-14.
#
# Epoch 08767: ReduceLROnPlateau reducing learning rate to 1.7398091634360755e-14.
#
# Epoch 08782: ReduceLROnPlateau reducing learning rate to 1.6528187696387757e-14.
#
# Epoch 08797: ReduceLROnPlateau reducing learning rate to 1.57017783920365e-14.
#
# Epoch 08812: ReduceLROnPlateau reducing learning rate to 1.4916689472434673e-14.
#
# Epoch 08827: ReduceLROnPlateau reducing learning rate to 1.4170854516004161e-14.
#
# Epoch 08842: ReduceLROnPlateau reducing learning rate to 1.3462311709735822e-14.
#
# Epoch 08857: ReduceLROnPlateau reducing learning rate to 1.2789195802376511e-14.
#
# Epoch 08872: ReduceLROnPlateau reducing learning rate to 1.2149735690385165e-14.
#
# Epoch 08887: ReduceLROnPlateau reducing learning rate to 1.1542248785163713e-14.
#
# Epoch 08902: ReduceLROnPlateau reducing learning rate to 1.0965136184969266e-14.
#
# Epoch 08917: ReduceLROnPlateau reducing learning rate to 1.0416879456188934e-14.
#
# Epoch 08932: ReduceLROnPlateau reducing learning rate to 9.896035805252007e-15.
#
# Epoch 08947: ReduceLROnPlateau reducing learning rate to 9.401234055223472e-15.
#
# Epoch 08962: ReduceLROnPlateau reducing learning rate to 8.931172231760103e-15.
#
# Epoch 08977: ReduceLROnPlateau reducing learning rate to 8.484613539703969e-15.
#
# Epoch 08992: ReduceLROnPlateau reducing learning rate to 8.060383144357224e-15.
#
# Epoch 09007: ReduceLROnPlateau reducing learning rate to 7.657364148075623e-15.
#
# Epoch 09022: ReduceLROnPlateau reducing learning rate to 7.274495980905907e-15.
#
# Epoch 09037: ReduceLROnPlateau reducing learning rate to 6.910771181860612e-15.
#
# Epoch 09052: ReduceLROnPlateau reducing learning rate to 6.565232582533516e-15.
#
# Epoch 09067: ReduceLROnPlateau reducing learning rate to 6.2369708930557425e-15.
#
# Epoch 09082: ReduceLROnPlateau reducing learning rate to 5.925122288051858e-15.
#
# Epoch 09097: ReduceLROnPlateau reducing learning rate to 5.628865992595973e-15.
#
# Epoch 09112: ReduceLROnPlateau reducing learning rate to 5.3474226728491415e-15.
#
# Epoch 09127: ReduceLROnPlateau reducing learning rate to 5.080051619674815e-15.
#
# Epoch 09142: ReduceLROnPlateau reducing learning rate to 4.8260491392762364e-15.
#
# Epoch 09157: ReduceLROnPlateau reducing learning rate to 4.584746541493197e-15.
#
# Epoch 09172: ReduceLROnPlateau reducing learning rate to 4.3555093351207326e-15.
#
# Epoch 09187: ReduceLROnPlateau reducing learning rate to 4.137734009183923e-15.
#
# Epoch 09202: ReduceLROnPlateau reducing learning rate to 3.930847228256597e-15.
#
# Epoch 09217: ReduceLROnPlateau reducing learning rate to 3.734305027780027e-15.
#
# Epoch 09232: ReduceLROnPlateau reducing learning rate to 3.5475895953377332e-15.
#
# Epoch 09247: ReduceLROnPlateau reducing learning rate to 3.3702100753367817e-15.
#
# Epoch 09262: ReduceLROnPlateau reducing learning rate to 3.20169955145291e-15.
#
# Epoch 09277: ReduceLROnPlateau reducing learning rate to 3.041614644289878e-15.
#
# Epoch 09292: ReduceLROnPlateau reducing learning rate to 2.889533902016868e-15.
#
# Epoch 09307: ReduceLROnPlateau reducing learning rate to 2.7450571968575085e-15.
#
# Epoch 09322: ReduceLROnPlateau reducing learning rate to 2.6078043168976005e-15.
#
# Epoch 09337: ReduceLROnPlateau reducing learning rate to 2.477414161403818e-15.
#
# Epoch 09352: ReduceLROnPlateau reducing learning rate to 2.353543533801757e-15.
#
# Epoch 09367: ReduceLROnPlateau reducing learning rate to 2.235866336994637e-15.
#
# Epoch 09382: ReduceLROnPlateau reducing learning rate to 2.1240729698523237e-15.
#
# Epoch 09397: ReduceLROnPlateau reducing learning rate to 2.0178693213597074e-15.
#
# Epoch 09412: ReduceLROnPlateau reducing learning rate to 1.916975764765076e-15.
#
# Epoch 09427: ReduceLROnPlateau reducing learning rate to 1.8211269564097897e-15.
#
# Epoch 09442: ReduceLROnPlateau reducing learning rate to 1.7300706287063326e-15.
#
# Epoch 09457: ReduceLROnPlateau reducing learning rate to 1.6435670872124998e-15.
#
# Epoch 09472: ReduceLROnPlateau reducing learning rate to 1.561388707705584e-15.
#
# Epoch 09487: ReduceLROnPlateau reducing learning rate to 1.4833192320862398e-15.
#
# Epoch 09502: ReduceLROnPlateau reducing learning rate to 1.4091532654526697e-15.
#
# Epoch 09517: ReduceLROnPlateau reducing learning rate to 1.3386955720044875e-15.
#
# Epoch 09532: ReduceLROnPlateau reducing learning rate to 1.2717607732872306e-15.
#
# Epoch 09547: ReduceLROnPlateau reducing learning rate to 1.2081727446813854e-15.
#
# Epoch 09562: ReduceLROnPlateau reducing learning rate to 1.1477641124765742e-15.
#
# Epoch 09577: ReduceLROnPlateau reducing learning rate to 1.0903759521160686e-15.
#
# Epoch 09592: ReduceLROnPlateau reducing learning rate to 1.035857184685814e-15.
#
# Epoch 09607: ReduceLROnPlateau reducing learning rate to 9.84064275158942e-16.
#
# Epoch 09622: ReduceLROnPlateau reducing learning rate to 9.34861031225446e-16.
#
# Epoch 09637: ReduceLROnPlateau reducing learning rate to 8.881179997812064e-16.
#
# Epoch 09652: ReduceLROnPlateau reducing learning rate to 8.437121148799205e-16.
#
# Epoch 09667: ReduceLROnPlateau reducing learning rate to 8.015264965627791e-16.
#
# Epoch 09682: ReduceLROnPlateau reducing learning rate to 7.614501491029785e-16.
#
# Epoch 09697: ReduceLROnPlateau reducing learning rate to 7.23377659250233e-16.
#
# Epoch 09712: ReduceLROnPlateau reducing learning rate to 6.872087938901249e-16.
#
# Epoch 09727: ReduceLROnPlateau reducing learning rate to 6.528483491663604e-16.
#
# Epoch 09742: ReduceLROnPlateau reducing learning rate to 6.202059493104459e-16.
#
# Epoch 09757: ReduceLROnPlateau reducing learning rate to 5.891956443010364e-16.
#
# Epoch 09772: ReduceLROnPlateau reducing learning rate to 5.597358595713555e-16.
#
# Epoch 09787: ReduceLROnPlateau reducing learning rate to 5.317490439611262e-16.
#
# Epoch 09802: ReduceLROnPlateau reducing learning rate to 5.051615691314084e-16.
#
# Epoch 09817: ReduceLROnPlateau reducing learning rate to 4.799034781016926e-16.
#
# Epoch 09832: ReduceLROnPlateau reducing learning rate to 4.559082840795755e-16.
#
# Epoch 09847: ReduceLROnPlateau reducing learning rate to 4.331128698755967e-16.
#
# Epoch 09862: ReduceLROnPlateau reducing learning rate to 4.114572364403331e-16.
#
# Epoch 09877: ReduceLROnPlateau reducing learning rate to 3.9088437713294554e-16.
#
# Epoch 09892: ReduceLROnPlateau reducing learning rate to 3.713401519897256e-16.
#
# Epoch 09907: ReduceLROnPlateau reducing learning rate to 3.527731368463521e-16.
#
# Epoch 09922: ReduceLROnPlateau reducing learning rate to 3.351344724601473e-16.
#
# Epoch 09937: ReduceLROnPlateau reducing learning rate to 3.183777387786237e-16.
#
# Epoch 09952: ReduceLROnPlateau reducing learning rate to 3.024588543543216e-16.
#
# Epoch 09967: ReduceLROnPlateau reducing learning rate to 2.8733590032077476e-16.
#
# Epoch 09982: ReduceLROnPlateau reducing learning rate to 2.7296909524621975e-16.
#
# Epoch 09997: ReduceLROnPlateau reducing learning rate to 2.5932064425585235e-16.

# %%
 ''' show the history of the current model '''
train_rmse = np.array(result['history'].history['root_mean_squared_error'])
dev_rmse = np.array(result['history'].history['val_root_mean_squared_error'])

import matplotlib.pyplot as plt
plt.figure()
plt.plot(range(len(train_rmse)),train_rmse,'-')
plt.plot(range(len(dev_rmse)),dev_rmse,'-')
plt.plot(np.argmin(dev_rmse),np.min(dev_rmse),'r*')
plt.text(np.argmin(dev_rmse)+50,np.min(dev_rmse)+50,str(np.min(dev_rmse)))
# Out:
# Text(1601, 239.81629943847656, '189.81629943847656')

# %%
 ''' show the history of the current model '''
R2 = np.array(result['history'].history['R2'])
val_R2 = np.array(result['history'].history['val_R2'])

import matplotlib.pyplot as plt
plt.figure()
plt.plot(range(len(R2)),R2,'-')
plt.plot(range(len(val_R2)),val_R2,'-')
plt.plot(np.argmax(val_R2),np.max(val_R2),'r*')
plt.text(np.argmax(val_R2)-0.3,np.max(val_R2)-0.3,str(np.max(val_R2)))
# Out:
# Text(1550.7, 0.6086365699768066, '0.9086365699768066')

# %% [markdown]
# # validation

# %%
''' validation '''
bestModel = result['bestModel']
train_part,dev_part = result['train_dev_set']

# %%
train_fea = train_part[:,:-1]
train_tar = train_part[:,-1]
dev_fea = dev_part[:,:-1]
dev_tar = dev_part[:,-1]

# %%
''' customizing metric R2 '''
def R2(y_true, y_pred):
  if type(y_true) == 'numpy.ndarray':
    y_true = tf.constant(y_true)
    y_pred = tf.constant(y_pred)
  flat_ture = tf.reshape(y_true, [-1])
  flat_prd = tf.reshape(y_pred, [-1])
  RSS = tf.math.reduce_sum((tf.math.square(flat_ture - flat_prd)),axis=-1)
  TSS = tf.math.reduce_sum(tf.math.square(flat_ture - tf.reduce_mean(flat_ture,axis=-1)))
  return 1-RSS/TSS

# %%
R2(train_tar.astype(float),bestModel.predict(train_fea).astype(float))
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.9388923451809278>

# %%
R2(dev_tar.astype(float), bestModel.predict(dev_fea).astype(float))
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.9086365569977294>

# %%
whole_fea = np.concatenate((train_fea,dev_fea))
whole_tar = np.concatenate((train_tar,dev_tar))

R2(whole_tar.astype(float), bestModel.predict(whole_fea).astype(float))
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.9342090039159487>

# %%
plt.figure()
ax = plt.hist(whole_tar, bins=100, facecolor="blue", edgecolor="black", alpha=0.7)

# %%
plt.figure()
ax = plt.hist( bestModel.predict(whole_fea).astype(float), bins=100, facecolor="blue", edgecolor="black", alpha=0.7)

# %%
plt.scatter(whole_tar,bestModel.predict(whole_fea).astype(float))

# %% [markdown]
# # save results

# %%
''' save model and parameters '''
result['bestModel'].save('bestModel.h5')
pd.DataFrame(result['history'].history).to_csv('history.csv')
np.save('train_arr.npy',result['train_dev_set'][0])
np.save('dev_arr.npy',result['train_dev_set'][1])
from joblib import dump, load
dump(result['normalizer'],'scaler.joblib')
